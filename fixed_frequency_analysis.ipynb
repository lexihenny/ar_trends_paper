# %%
import numpy as np
import xarray as xr
import scipy.stats as st
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import requests
import os,errno
import sys
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER,LATITUDE_FORMATTER
import matplotlib.ticker as mticker
import cartopy.feature as cfeature
import datetime as dt
import pandas as pd
import time
import urllib.request
import metpy.calc as mpcalc
import salem
import scipy.optimize as opt
import warnings
import geopy.distance
import matplotlib as mpl
from scipy.spatial import ConvexHull

from scipy.ndimage.measurements import label
from scipy.ndimage import binary_dilation

warnings.filterwarnings('ignore')

dir_data='/Users/ahenny/'
dir3='/Volumes/My Passport/'
dir2='/Volumes/Extreme Pro/'

# %%
if 1==0:
    ds=xr.open_dataset(dir_data+'land_area_intercomparison.nc')
    grids_list_era5_variable=ds['grids_list_era5_variable'].values.tolist()
    grids_list_era5_fixed=ds['grids_list_era5_fixed'].values.tolist()
    grids_list_era5_fixed_poleward=ds['grids_list_era5_fixed_poleward'].values.tolist()

    grids_list_merra2_variable=ds['grids_list_merra2_variable'].values.tolist()
    grids_list_merra2_fixed=ds['grids_list_merra2_fixed'].values.tolist()
    grids_list_merra2_fixed_poleward=ds['grids_list_merra2_fixed_poleward'].values.tolist()

    grids_list_jra55_variable=ds['grids_list_jra55_variable'].values.tolist()
    grids_list_jra55_fixed=ds['grids_list_jra55_fixed'].values.tolist()
    grids_list_jra55_fixed_poleward=ds['grids_list_jra55_fixed_poleward'].values.tolist()

    grids_list_era5tp=ds['grids_list_era5tp'].values.tolist()
    grids_list_era5reid=ds['grids_list_era5reid'].values.tolist()
    grids_list_era5mk=ds['grids_list_era5mk'].values.tolist()

    grids_list_merra2lo=ds['grids_list_merra2lo'].values.tolist()
    grids_list_merra2cndl=ds['grids_list_merra2cndl'].values.tolist()
    grids_list_merra2ac=ds['grids_list_merra2ac'].values.tolist()

    grids_list_jra55gw=ds['grids_list_jra55gw'].values.tolist()


    areas_list_era5_variable=ds['areas_list_era5_variable'].values.tolist()
    areas_list_era5_fixed=ds['areas_list_era5_fixed'].values.tolist()
    areas_list_era5_fixed_poleward=ds['areas_list_era5_fixed_poleward'].values.tolist()

    areas_list_merra2_variable=ds['areas_list_merra2_variable'].values.tolist()
    areas_list_merra2_fixed=ds['areas_list_merra2_fixed'].values.tolist()
    areas_list_merra2_fixed_poleward=ds['areas_list_merra2_fixed_poleward'].values.tolist()

    areas_list_jra55_variable=ds['areas_list_jra55_variable'].values.tolist()
    areas_list_jra55_fixed=ds['areas_list_jra55_fixed'].values.tolist()
    areas_list_jra55_fixed_poleward=ds['areas_list_jra55_fixed_poleward'].values.tolist()

    areas_list_era5tp=ds['areas_list_era5tp'].values.tolist()
    areas_list_era5reid=ds['areas_list_era5reid'].values.tolist()
    areas_list_era5mk=ds['areas_list_era5mk'].values.tolist()

    areas_list_merra2lo=ds['areas_list_merra2lo'].values.tolist()
    areas_list_merra2cndl=ds['areas_list_merra2cndl'].values.tolist()
    areas_list_merra2ac=ds['areas_list_merra2ac'].values.tolist()

    areas_list_jra55gw=ds['areas_list_jra55gw'].values.tolist()

if 1==1:
    
    ds=xr.open_dataset(dir_data+'time_series_simple_era5.nc')
    areas_list_era5_fixed=ds['area_list_era5_fixed'].values.tolist()
    areas_list_era5_fixed_poleward=ds['area_list_era5_poleward'].values.tolist()
    areas_list_era5_variable=ds['area_list_era5_variable'].values.tolist()

    ds=xr.open_dataset(dir_data+'time_series_simple_merra2.nc')
    areas_list_merra2_fixed=ds['area_list_merra2_fixed'].values.tolist()
    areas_list_merra2_fixed_poleward=ds['area_list_merra2_poleward'].values.tolist()
    areas_list_merra2_variable=ds['area_list_merra2_variable'].values.tolist()

    ds=xr.open_dataset(dir_data+'time_series_simple_jra55.nc')
    areas_list_jra55_fixed=ds['area_list_jra55_fixed'].values.tolist()
    areas_list_jra55_fixed_poleward=ds['area_list_jra55_poleward'].values.tolist()
    areas_list_jra55_variable=ds['area_list_jra55_variable'].values.tolist()


    ds=xr.open_dataset(dir_data+'time_series_simple_era5tp.nc')
    areas_list_era5tp=ds['area_list_era5tp'].values.tolist()

    ds=xr.open_dataset(dir_data+'time_series_simple_era5mk_fixed.nc')#_fixed
    areas_list_era5mk=ds['area_list_era5mk'].values.tolist()

    ds=xr.open_dataset(dir_data+'time_series_simple_merra2ac.nc')
    areas_list_merra2ac=ds['area_list_merra2ac'].values.tolist()

    ds=xr.open_dataset(dir_data+'time_series_simple_merra2lo.nc')
    areas_list_merra2lo=ds['area_list_merra2lo'].values.tolist()

    ds=xr.open_dataset(dir_data+'time_series_simple_jra55gw.nc')
    areas_list_jra55gw=ds['area_list_jra55gw'].values.tolist()

    ds=xr.open_dataset(dir_data+'time_series_simple_merra2cndl.nc')
    areas_list_merra2cndl=ds['area_list_merra2cndl'].values.tolist()

    ds=xr.open_dataset(dir_data+'time_series_simple_era5reid.nc')
    areas_list_era5reid=ds['area_list_era5reid'].values.tolist()

percent=0.5
if 1==1:
    q1_era5_variable=float(sum(areas_list_era5_variable))/float(len(areas_list_era5_variable))*percent
    q1_era5_fixed=float(sum(areas_list_era5_fixed))/float(len(areas_list_era5_fixed))*percent
    q1_era5_fixed_poleward=float(sum(areas_list_era5_fixed_poleward))/float(len(areas_list_era5_fixed_poleward))*percent

    q1_merra2_variable=float(sum(areas_list_merra2_variable))/float(len(areas_list_merra2_variable))*percent
    q1_merra2_fixed=float(sum(areas_list_merra2_fixed))/float(len(areas_list_merra2_fixed))*percent
    q1_merra2_fixed_poleward=float(sum(areas_list_merra2_fixed_poleward))/float(len(areas_list_merra2_fixed_poleward))*percent

    q1_jra55_variable=float(sum(areas_list_jra55_variable))/float(len(areas_list_jra55_variable))*percent
    q1_jra55_fixed=float(sum(areas_list_jra55_fixed))/float(len(areas_list_jra55_fixed))*percent
    q1_jra55_fixed_poleward=float(sum(areas_list_jra55_fixed_poleward))/float(len(areas_list_jra55_fixed_poleward))*percent

    q1_era5tp=float(sum(areas_list_era5tp))/float(len(areas_list_era5tp))*percent
    q1_era5reid=float(sum(areas_list_era5reid))/float(len(areas_list_era5reid))*percent
    q1_era5mk=float(sum(areas_list_era5mk))/float(len(areas_list_era5mk))*percent

    q1_merra2lo=float(sum(areas_list_merra2lo))/float(len(areas_list_merra2lo))*percent
    q1_merra2cndl=float(sum(areas_list_merra2cndl))/float(len(areas_list_merra2cndl))*percent
    q1_merra2ac=float(sum(areas_list_merra2ac))/float(len(areas_list_merra2ac))*percent

    q1_jra55gw=float(sum(areas_list_jra55gw))/float(len(areas_list_jra55gw))*percent

    test=[x for x in areas_list_era5_variable if x<q1_era5_variable]
    print(test)
    test=[x for x in areas_list_era5_fixed if x<q1_era5_fixed]
    print(test)
    test=[x for x in areas_list_era5_fixed_poleward if x<q1_era5_fixed_poleward]
    print(test)

    test=[x for x in areas_list_merra2_variable if x<q1_merra2_variable]
    print(test)
    test=[x for x in areas_list_merra2_fixed if x<q1_merra2_fixed]
    print(test)
    test=[x for x in areas_list_merra2_fixed_poleward if x<q1_merra2_fixed_poleward]
    print(test)

    test=[x for x in areas_list_jra55_variable if x<q1_jra55_variable]
    print(test)
    test=[x for x in areas_list_jra55_fixed if x<q1_jra55_fixed]
    print(test)
    test=[x for x in areas_list_jra55_fixed_poleward if x<q1_jra55_fixed_poleward]
    print(test)

    test=[x for x in areas_list_era5tp if x<q1_era5tp]
    print(test)
    test=[x for x in areas_list_era5reid if x<q1_era5reid]
    print(test)
    test=[x for x in areas_list_era5mk if x<q1_era5mk]
    print(test)

    test=[x for x in areas_list_merra2lo if x<q1_merra2lo]
    print(test)
    test=[x for x in areas_list_merra2cndl if x<q1_merra2cndl]
    print(test)
    test=[x for x in areas_list_merra2ac if x<q1_merra2ac]
    print(test)

    test=[x for x in areas_list_jra55gw if x<q1_jra55gw]
    print(test)

# %%
print(q1_merra2lo/365./4./148326000)

# %%
ds=xr.open_dataset(dir2+'merra2_gridareas.nc')
areas=ds['cell_area']/1e6

ivt_list_era5_variable=[]
iwv_list_era5_variable=[]
s_list_era5_variable=[]
mfc_list_era5_variable=[]

ivt_list_era5_fixed=[]
iwv_list_era5_fixed=[]
s_list_era5_fixed=[]
mfc_list_era5_fixed=[]

ivt_list_era5_fixed_poleward=[]
iwv_list_era5_fixed_poleward=[]
s_list_era5_fixed_poleward=[]
mfc_list_era5_fixed_poleward=[]
yrs=np.arange(1940,2024,1)
for i in range(len(yrs)):
    year=yrs[i]
    print(year)
    
    ds=xr.open_dataset('/Users/ahenny/Downloads/data.nc')
    t2m=ds['t2m'][0,:,:]
    land_mask=t2m/t2m
    land_mask=land_mask.fillna(0)
        
    lon_east=[x for x in land_mask.longitude.values if x>=180.]
    lon_west=[x for x in land_mask.longitude.values if x<180.]
    l_east=land_mask.sel(longitude=lon_east)
    l_west=land_mask.sel(longitude=lon_west)
    l_east['longitude']=[x-360. for x in lon_east]
    land_mask=xr.concat([l_east,l_west],dim='longitude')
        
    dk=xr.Dataset()
    dk['land']=(('lat','lon'),land_mask.values)
    dk.coords['lat']=land_mask.latitude.values
    dk.coords['lon']=land_mask.longitude.values
        
    land_mask=dk['land']
    
    ds=xr.open_dataset(dir2+'era5.ar.labels.model.variable.'+str(year)+'.nc')
    labeled=ds['ar_labeled']
    land_mask_interp=land_mask.interp_like(labeled[0,:,:])
    labeled=labeled.where(land_mask_interp>=0.5)
    binary=labeled/labeled
    
    
    if 1==1:
        ds=xr.open_dataset(dir2+'era_5_ivtinterp_'+str(year)+'.nc')
        ivt=ds['ivt'][:,:,:]
        ds=xr.open_dataset(dir2+'era_5_iwvinterp_'+str(year)+'.nc')
        iwv=ds['iwv'][:,:,:]
        ds=xr.open_dataset(dir2+'era_5_u850interp_'+str(year)+'.nc')
        u=ds['u']
        ds=xr.open_dataset(dir2+'era_5_v850interp_'+str(year)+'.nc')
        v=ds['v']
        s=np.sqrt(u**2+v**2)

        ds=xr.open_dataset(dir2+'era_5_mfcinterp_'+str(year)+'.nc')#era5 is divergence
        mfc=ds['mfc'][:,:,:]*-1.
    if 1==0:
        ds=xr.open_dataset(dir2+'merra2.ivt.3hr.model.'+str(year)+'.nc')
        ivt=ds['ivt'][0::2,:,:]
        ds=xr.open_dataset(dir2+'merra2.iwv.3hr.model.'+str(year)+'.nc')
        iwv=ds['iwv'][0::2,:,:]
        ds=xr.open_dataset(dir3+'merra2.u850.6hr.'+str(year)+'.nc')
        u=ds['u']
        ds=xr.open_dataset(dir3+'merra2.v850.6hr.'+str(year)+'.nc')
        v=ds['v']
        s=np.sqrt(u**2+v**2)
        
        ds=xr.open_dataset(dir2+'merra2.mfc.3hr.model.'+str(year)+'.nc')#merra-2 is tendency
        mfc=ds['mfc'][0::2,:,:]
    
    
    ivt['lon']=labeled.lon.values
    iwv['lon']=labeled.lon.values
    s['lon']=labeled.lon.values
    mfc['lon']=labeled.lon.values
        
    ivt['lat']=labeled.lat.values
    iwv['lat']=labeled.lat.values
    s['lat']=labeled.lat.values
    mfc['lat']=labeled.lat.values
    
    ivt['time']=labeled.time.values
    iwv['time']=labeled.time.values
    s['time']=labeled.time.values
    mfc['time']=labeled.time.values
    
    areas['lat']=labeled.lat.values
    areas['lon']=labeled.lon.values
    
    var_sel=ivt.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_era5_variable:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    ivt_list_era5_variable.append(var_mean)
    print(var_mean)
    
    print(q1_era5_variable)
    print(sum_area)
    sum2=0
    for j in range(var_sel.time.size):
        area=areas.where(var_sel[j]>=threshold)
        sum1=area.sum().values.tolist()
        sum2=sum2+sum1
    print(sum2)
    #sys.exit()

    var_sel=iwv.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_era5_variable:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    iwv_list_era5_variable.append(var_mean)
    print(var_mean)
    print(q1_era5_variable)
    print(sum_area)
    sum2=0
    for j in range(var_sel.time.size):
        area=areas.where(var_sel[j]>=threshold)
        sum1=area.sum().values.tolist()
        sum2=sum2+sum1
    print(sum2)
    
    var_sel=s.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_era5_variable:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    s_list_era5_variable.append(var_mean)
    print(var_mean)
    
    print(q1_era5_variable)
    print(sum_area)
    sum2=0
    for j in range(var_sel.time.size):
        area=areas.where(var_sel[j]>=threshold)
        sum1=area.sum().values.tolist()
        sum2=sum2+sum1
    print(sum2)
    
    var_sel=mfc.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_era5_variable:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    mfc_list_era5_variable.append(var_mean)
    print(var_mean)
    
    print(q1_era5_variable)
    print(sum_area)
    sum2=0
    for j in range(var_sel.time.size):
        area=areas.where(var_sel[j]>=threshold)
        sum1=area.sum().values.tolist()
        sum2=sum2+sum1
    print(sum2)
    
    
    ###
    
    ds=xr.open_dataset(dir2+'era5.ar.labels.model.'+str(year)+'.nc')
    labeled=ds['ar_labeled']
    land_mask_interp=land_mask.interp_like(labeled[0,:,:])
    labeled=labeled.where(land_mask_interp>=0.5)
    binary=labeled/labeled
    
    ivt['lon']=labeled.lon.values
    iwv['lon']=labeled.lon.values
    s['lon']=labeled.lon.values
    mfc['lon']=labeled.lon.values
        
    ivt['lat']=labeled.lat.values
    iwv['lat']=labeled.lat.values
    s['lat']=labeled.lat.values
    mfc['lat']=labeled.lat.values
    
    ivt['time']=labeled.time.values
    iwv['time']=labeled.time.values
    s['time']=labeled.time.values
    mfc['time']=labeled.time.values
    
    areas['lat']=labeled.lat.values
    areas['lon']=labeled.lon.values
    
    var_sel=ivt.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_era5_fixed:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    ivt_list_era5_fixed.append(var_mean)
    print(var_mean)


    var_sel=iwv.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_era5_fixed:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    iwv_list_era5_fixed.append(var_mean)
    print(var_mean)
    
    var_sel=s.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_era5_fixed:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    s_list_era5_fixed.append(var_mean)
    print(var_mean)
    
    var_sel=mfc.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_era5_fixed:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    mfc_list_era5_fixed.append(var_mean)
    print(var_mean)
    
    ###
    
    ds=xr.open_dataset(dir2+'era5.ar.labels.model.poleward.'+str(year)+'.nc')
    labeled=ds['ar_labeled']
    land_mask_interp=land_mask.interp_like(labeled[0,:,:])
    labeled=labeled.where(land_mask_interp>=0.5)
    binary=labeled/labeled
    
    ivt['lon']=labeled.lon.values
    iwv['lon']=labeled.lon.values
    s['lon']=labeled.lon.values
    mfc['lon']=labeled.lon.values
        
    ivt['lat']=labeled.lat.values
    iwv['lat']=labeled.lat.values
    s['lat']=labeled.lat.values
    mfc['lat']=labeled.lat.values
    
    ivt['time']=labeled.time.values
    iwv['time']=labeled.time.values
    s['time']=labeled.time.values
    mfc['time']=labeled.time.values
    
    areas['lat']=labeled.lat.values
    areas['lon']=labeled.lon.values
    
    var_sel=ivt.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_era5_fixed_poleward:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    ivt_list_era5_fixed_poleward.append(var_mean)
    print(var_mean)


    var_sel=iwv.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_era5_fixed_poleward:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    iwv_list_era5_fixed_poleward.append(var_mean)
    print(var_mean)
    
    var_sel=s.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_era5_fixed_poleward:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    s_list_era5_fixed_poleward.append(var_mean)
    print(var_mean)
    
    var_sel=mfc.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_era5_fixed_poleward:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    mfc_list_era5_fixed_poleward.append(var_mean)
    print(var_mean)

# %%
dk=xr.Dataset()
dk['ivt_list_era5_variable']=(('time'),ivt_list_era5_variable)
dk['ivt_list_era5_fixed']=(('time'),ivt_list_era5_fixed)
dk['ivt_list_era5_fixed_poleward']=(('time'),ivt_list_era5_fixed_poleward)

dk['iwv_list_era5_variable']=(('time'),iwv_list_era5_variable)
dk['iwv_list_era5_fixed']=(('time'),iwv_list_era5_fixed)
dk['iwv_list_era5_fixed_poleward']=(('time'),iwv_list_era5_fixed_poleward)

dk['s_list_era5_variable']=(('time'),s_list_era5_variable)
dk['s_list_era5_fixed']=(('time'),s_list_era5_fixed)
dk['s_list_era5_fixed_poleward']=(('time'),s_list_era5_fixed_poleward)

dk['mfc_list_era5_variable']=(('time'),mfc_list_era5_variable)
dk['mfc_list_era5_fixed']=(('time'),mfc_list_era5_fixed)
dk['mfc_list_era5_fixed_poleward']=(('time'),mfc_list_era5_fixed_poleward)

dk.coords['time']=yrs

try:
    os.remove(dir_data+'land_synoptic_intercomp_era5_60.nc')
except OSError:
    pass
dk.to_netcdf(dir_data+'land_synoptic_intercomp_era5_60.nc',mode='w',format='NETCDF4')

# %%
fig=plt.figure(figsize=(12,12))
ax=plt.subplot(1,1,1)
ax.plot(yrs,iwv_list_era5_variable)
plt.show()

# %%
ds=xr.open_dataset(dir2+'merra2_gridareas.nc')
areas=ds['cell_area']/1e6

ivt_list_variable=[]
iwv_list_variable=[]
s_list_variable=[]
mfc_list_variable=[]

ivt_list_fixed=[]
iwv_list_fixed=[]
s_list_fixed=[]
mfc_list_fixed=[]

ivt_list_fixed_poleward=[]
iwv_list_fixed_poleward=[]
s_list_fixed_poleward=[]
mfc_list_fixed_poleward=[]
yrs=np.arange(1980,2024,1)
for i in range(len(yrs)):
    year=yrs[i]
    print(year)
    
    ds=xr.open_dataset('/Users/ahenny/Downloads/data.nc')
    t2m=ds['t2m'][0,:,:]
    land_mask=t2m/t2m
    land_mask=land_mask.fillna(0)
        
    lon_east=[x for x in land_mask.longitude.values if x>=180.]
    lon_west=[x for x in land_mask.longitude.values if x<180.]
    l_east=land_mask.sel(longitude=lon_east)
    l_west=land_mask.sel(longitude=lon_west)
    l_east['longitude']=[x-360. for x in lon_east]
    land_mask=xr.concat([l_east,l_west],dim='longitude')
        
    dk=xr.Dataset()
    dk['land']=(('lat','lon'),land_mask.values)
    dk.coords['lat']=land_mask.latitude.values
    dk.coords['lon']=land_mask.longitude.values
        
    land_mask=dk['land']
    
    ds=xr.open_dataset(dir2+'merra2.ar.labels.model.variable.'+str(year)+'.nc')
    labeled=ds['ar_labeled']
    land_mask_interp=land_mask.interp_like(labeled[0,:,:])
    labeled=labeled.where(land_mask_interp>=0.5)
    binary=labeled/labeled

    if 1==1:
        ds=xr.open_dataset(dir2+'merra2.ivt.3hr.model.'+str(year)+'.nc')
        ivt=ds['ivt'][0::2,:,:]
        ds=xr.open_dataset(dir2+'merra2.iwv.3hr.model.'+str(year)+'.nc')
        iwv=ds['iwv'][0::2,:,:]
        ds=xr.open_dataset(dir3+'merra2.u850.6hr.'+str(year)+'.nc')
        u=ds['u']
        ds=xr.open_dataset(dir3+'merra2.v850.6hr.'+str(year)+'.nc')
        v=ds['v']
        s=np.sqrt(u**2+v**2)
        
        ds=xr.open_dataset(dir2+'merra2.mfc.3hr.model.'+str(year)+'.nc')#merra-2 is tendency
        mfc=ds['mfc'][0::2,:,:]
    
    
    ivt['lon']=labeled.lon.values
    iwv['lon']=labeled.lon.values
    s['lon']=labeled.lon.values
    mfc['lon']=labeled.lon.values
        
    ivt['lat']=labeled.lat.values
    iwv['lat']=labeled.lat.values
    s['lat']=labeled.lat.values
    mfc['lat']=labeled.lat.values
    
    ivt['time']=labeled.time.values
    iwv['time']=labeled.time.values
    s['time']=labeled.time.values
    mfc['time']=labeled.time.values
    
    areas['lat']=labeled.lat.values
    areas['lon']=labeled.lon.values
    
    var_sel=ivt.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_merra2_variable:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    ivt_list_variable.append(var_mean)
    print(var_mean)


    var_sel=iwv.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_merra2_variable:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    iwv_list_variable.append(var_mean)
    print(var_mean)
    
    
    var_sel=s.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_merra2_variable:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    s_list_variable.append(var_mean)
    print(var_mean)
    
    
    var_sel=mfc.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_merra2_variable:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    mfc_list_variable.append(var_mean)
    print(var_mean)
    
    
    ###
    
    ds=xr.open_dataset(dir2+'merra2.ar.labels.model.'+str(year)+'.nc')
    labeled=ds['ar_labeled'][0::2,:,:]
    land_mask_interp=land_mask.interp_like(labeled[0,:,:])
    labeled=labeled.where(land_mask_interp>=0.5)
    binary=labeled/labeled
    
    ivt['lon']=labeled.lon.values
    iwv['lon']=labeled.lon.values
    s['lon']=labeled.lon.values
    mfc['lon']=labeled.lon.values
        
    ivt['lat']=labeled.lat.values
    iwv['lat']=labeled.lat.values
    s['lat']=labeled.lat.values
    mfc['lat']=labeled.lat.values
    
    ivt['time']=labeled.time.values
    iwv['time']=labeled.time.values
    s['time']=labeled.time.values
    mfc['time']=labeled.time.values
    
    areas['lat']=labeled.lat.values
    areas['lon']=labeled.lon.values
    
    var_sel=ivt.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_merra2_fixed:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    ivt_list_fixed.append(var_mean)
    print(var_mean)


    var_sel=iwv.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_merra2_fixed:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    iwv_list_fixed.append(var_mean)
    print(var_mean)
    
    
    var_sel=s.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_merra2_fixed:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    s_list_fixed.append(var_mean)
    print(var_mean)
    
    var_sel=mfc.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_merra2_fixed:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    mfc_list_fixed.append(var_mean)
    print(var_mean)
    
    ###
    
    ds=xr.open_dataset(dir2+'merra2.ar.labels.model.poleward.'+str(year)+'.nc')
    labeled=ds['ar_labeled']
    land_mask_interp=land_mask.interp_like(labeled[0,:,:])
    labeled=labeled.where(land_mask_interp>=0.5)
    binary=labeled/labeled
    
    ivt['lon']=labeled.lon.values
    iwv['lon']=labeled.lon.values
    s['lon']=labeled.lon.values
    mfc['lon']=labeled.lon.values
        
    ivt['lat']=labeled.lat.values
    iwv['lat']=labeled.lat.values
    s['lat']=labeled.lat.values
    mfc['lat']=labeled.lat.values
    
    ivt['time']=labeled.time.values
    iwv['time']=labeled.time.values
    s['time']=labeled.time.values
    mfc['time']=labeled.time.values
    
    areas['lat']=labeled.lat.values
    areas['lon']=labeled.lon.values
    
    var_sel=ivt.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_merra2_fixed_poleward:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    ivt_list_fixed_poleward.append(var_mean)
    print(var_mean)


    var_sel=iwv.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_merra2_fixed_poleward:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    iwv_list_fixed_poleward.append(var_mean)
    print(var_mean)

    
    var_sel=s.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_merra2_fixed_poleward:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    s_list_fixed_poleward.append(var_mean)
    print(var_mean)

    
    var_sel=mfc.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_merra2_fixed_poleward:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    mfc_list_fixed_poleward.append(var_mean)
    print(var_mean)

# %%
fig=plt.figure(figsize=(12,12))
ax=plt.subplot(1,1,1)
ax.plot(yrs,iwv_list_variable)
plt.show()

# %%
dk=xr.Dataset()
dk['ivt_list_merra2_variable']=(('time'),ivt_list_variable)
dk['ivt_list_merra2_fixed']=(('time'),ivt_list_fixed)
dk['ivt_list_merra2_fixed_poleward']=(('time'),ivt_list_fixed_poleward)

dk['iwv_list_merra2_variable']=(('time'),iwv_list_variable)
dk['iwv_list_merra2_fixed']=(('time'),iwv_list_fixed)
dk['iwv_list_merra2_fixed_poleward']=(('time'),iwv_list_fixed_poleward)

dk['s_list_merra2_variable']=(('time'),s_list_variable)
dk['s_list_merra2_fixed']=(('time'),s_list_fixed)
dk['s_list_merra2_fixed_poleward']=(('time'),s_list_fixed_poleward)

dk['mfc_list_merra2_variable']=(('time'),mfc_list_variable)
dk['mfc_list_merra2_fixed']=(('time'),mfc_list_fixed)
dk['mfc_list_merra2_fixed_poleward']=(('time'),mfc_list_fixed_poleward)

dk.coords['time']=yrs

try:
    os.remove(dir_data+'land_synoptic_intercomp_merra2_60.nc')
except OSError:
    pass
dk.to_netcdf(dir_data+'land_synoptic_intercomp_merra2_60.nc',mode='w',format='NETCDF4')

# %%
ds=xr.open_dataset(dir_data+'jra55_gridareas.nc')
areas=ds['cell_area']/1e6

ivt_list_variable=[]
iwv_list_variable=[]
s_list_variable=[]
mfc_list_variable=[]

ivt_list_fixed=[]
iwv_list_fixed=[]
s_list_fixed=[]
mfc_list_fixed=[]

ivt_list_fixed_poleward=[]
iwv_list_fixed_poleward=[]
s_list_fixed_poleward=[]
mfc_list_fixed_poleward=[]
yrs=np.arange(1958,2024,1)
for i in range(len(yrs)):
    year=yrs[i]
    print(year)
    
    ds=xr.open_dataset('/Users/ahenny/Downloads/data.nc')
    t2m=ds['t2m'][0,:,:]
    land_mask=t2m/t2m
    land_mask=land_mask.fillna(0)
        
    lon_east=[x for x in land_mask.longitude.values if x>=180.]
    lon_west=[x for x in land_mask.longitude.values if x<180.]
    l_east=land_mask.sel(longitude=lon_east)
    l_west=land_mask.sel(longitude=lon_west)
    l_east['longitude']=[x-360. for x in lon_east]
    land_mask=xr.concat([l_east,l_west],dim='longitude')
        
    dk=xr.Dataset()
    dk['land']=(('lat','lon'),land_mask.values)
    dk.coords['lat']=land_mask.latitude.values
    dk.coords['lon']=land_mask.longitude.values
        
    land_mask=dk['land']
    
    ds=xr.open_dataset(dir3+'jra55_ivt_'+str(year)+'.nc')
    ivt=ds['ivt']
    ds=xr.open_dataset(dir3+'jra55_iwv_'+str(year)+'.nc')
    iwv=ds['iwv']
    ds=xr.open_dataset(dir3+'jra55_u850_'+str(year)+'.nc')
    u=ds['u']
    ds=xr.open_dataset(dir3+'jra55_v850_'+str(year)+'.nc')
    v=ds['v']
    s=np.sqrt(u**2+v**2)
    
    lons_west=[x for x in s.lon.values if x<-90]
    lons_east=[x for x in s.lon.values if x>=90]
    s_west=s.sel(lon=lons_west)
    s_east=s.sel(lon=lons_east)
    s_west['lon']=[x+360. for x in lons_west]
    s_east['lon']=[x-360. for x in lons_east]
    s_full=xr.concat([s_east,s,s_west],dim='lon')
    s_interp=s.interp(lon=ivt.lon.values,lat=ivt.lat.values)
    
    ds=xr.open_dataset(dir2+'jra55.ar.labels.model.variable.'+str(year)+'.nc')
    labeled=ds['ar_labeled']
    land_mask_interp=land_mask.interp_like(labeled[0,:,:])
    labeled=labeled.where(land_mask_interp>=0.5)
    binary=labeled/labeled
    
    ivt['lon']=binary.lon.values
    iwv['lon']=binary.lon.values
    s_interp['lon']=binary.lon.values
        
    ivt['lat']=binary.lat.values
    iwv['lat']=binary.lat.values
    s_interp['lat']=binary.lat.values
    
    ivt['time']=binary.time.values
    iwv['time']=binary.time.values
    s_interp['time']=binary.time.values
    
    areas['lat']=labeled.lat.values
    areas['lon']=labeled.lon.values
    
    
    var_sel=ivt.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_jra55_variable:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    ivt_list_variable.append(var_mean)
    print(var_mean)


    var_sel=iwv.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_jra55_variable:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    iwv_list_variable.append(var_mean)
    print(var_mean)
    
    
    var_sel=s_interp.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_jra55_variable:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    s_list_variable.append(var_mean)
    print(var_mean)
    
    
    ###
    
    ds=xr.open_dataset(dir_data+'jra55.ar.labels.model.'+str(year)+'.nc')
    labeled=ds['ar_labeled']
    land_mask_interp=land_mask.interp_like(labeled[0,:,:])
    labeled=labeled.where(land_mask_interp>=0.5)
    binary=labeled/labeled
    
    ivt['lon']=binary.lon.values
    iwv['lon']=binary.lon.values
    s_interp['lon']=binary.lon.values
        
    ivt['lat']=binary.lat.values
    iwv['lat']=binary.lat.values
    s_interp['lat']=binary.lat.values
    
    ivt['time']=binary.time.values
    iwv['time']=binary.time.values
    s_interp['time']=binary.time.values
    
    areas['lat']=labeled.lat.values
    areas['lon']=labeled.lon.values
    
    
    var_sel=ivt.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_jra55_fixed:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    ivt_list_fixed.append(var_mean)
    print(var_mean)


    var_sel=iwv.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_jra55_fixed:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    iwv_list_fixed.append(var_mean)
    print(var_mean)
    
    
    var_sel=s_interp.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_jra55_fixed:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    s_list_fixed.append(var_mean)
    print(var_mean)
    
    ###
    
    ds=xr.open_dataset(dir2+'jra55.ar.labels.model.poleward.'+str(year)+'.nc')
    labeled=ds['ar_labeled']
    land_mask_interp=land_mask.interp_like(labeled[0,:,:])
    labeled=labeled.where(land_mask_interp>=0.5)
    binary=labeled/labeled
    
    ivt['lon']=binary.lon.values
    iwv['lon']=binary.lon.values
    s_interp['lon']=binary.lon.values
        
    ivt['lat']=binary.lat.values
    iwv['lat']=binary.lat.values
    s_interp['lat']=binary.lat.values
    
    ivt['time']=binary.time.values
    iwv['time']=binary.time.values
    s_interp['time']=binary.time.values
    
    areas['lat']=labeled.lat.values
    areas['lon']=labeled.lon.values
    
    var_sel=ivt.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_jra55_fixed_poleward:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    ivt_list_fixed_poleward.append(var_mean)
    print(var_mean)


    var_sel=iwv.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_jra55_fixed_poleward:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    iwv_list_fixed_poleward.append(var_mean)
    print(var_mean)
    
    
    var_sel=s_interp.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_jra55_fixed_poleward:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    s_list_fixed_poleward.append(var_mean)
    print(var_mean)

# %%
dk=xr.Dataset()
dk['ivt_list_jra55_variable']=(('time'),ivt_list_variable)
dk['ivt_list_jra55_fixed']=(('time'),ivt_list_fixed)
dk['ivt_list_jra55_fixed_poleward']=(('time'),ivt_list_fixed_poleward)

dk['iwv_list_jra55_variable']=(('time'),iwv_list_variable)
dk['iwv_list_jra55_fixed']=(('time'),iwv_list_fixed)
dk['iwv_list_jra55_fixed_poleward']=(('time'),iwv_list_fixed_poleward)

dk['s_list_jra55_variable']=(('time'),s_list_variable)
dk['s_list_jra55_fixed']=(('time'),s_list_fixed)
dk['s_list_jra55_fixed_poleward']=(('time'),s_list_fixed_poleward)

dk.coords['time']=yrs

try:
    os.remove(dir_data+'land_synoptic_intercomp_jra55_60.nc')
except OSError:
    pass
dk.to_netcdf(dir_data+'land_synoptic_intercomp_jra55_60.nc',mode='w',format='NETCDF4')

# %%
ds=xr.open_dataset(dir2+'merra2_gridareas.nc')
areas=ds['cell_area']/1e6

ivt_list_merra2lo=[]
iwv_list_merra2lo=[]
s_list_merra2lo=[]
mfc_list_merra2lo=[]

ivt_list_merra2cndl=[]
iwv_list_merra2cndl=[]
s_list_merra2cndl=[]
mfc_list_merra2cndl=[]

ivt_list_merra2ac=[]
iwv_list_merra2ac=[]
s_list_merra2ac=[]
mfc_list_merra2ac=[]

yrs=np.arange(1980,2020,1)
for i in range(len(yrs)):
    year=yrs[i]
    print(year)
    
    ds=xr.open_dataset('/Users/ahenny/Downloads/data.nc')
    t2m=ds['t2m'][0,:,:]
    land_mask=t2m/t2m
    land_mask=land_mask.fillna(0)
        
    lon_east=[x for x in land_mask.longitude.values if x>=180.]
    lon_west=[x for x in land_mask.longitude.values if x<180.]
    l_east=land_mask.sel(longitude=lon_east)
    l_west=land_mask.sel(longitude=lon_west)
    l_east['longitude']=[x-360. for x in lon_east]
    land_mask=xr.concat([l_east,l_west],dim='longitude')
        
    dk=xr.Dataset()
    dk['land']=(('lat','lon'),land_mask.values)
    dk.coords['lat']=land_mask.latitude.values
    dk.coords['lon']=land_mask.longitude.values
        
    land_mask=dk['land']
    
    ds=xr.open_dataset(dir2+'merra2.ar.lorav2.'+str(year)+'.nc')
    ar=ds['ar']
    land_mask_interp=land_mask.interp_like(ar[0,:,:])
    ar=ar.where(land_mask_interp>=0.5)
    binary=ar.where(ar==1)

    if 1==1:
        ds=xr.open_dataset(dir2+'merra2.ivt.3hr.model.'+str(year)+'.nc')
        ivt=ds['ivt'][0::2,:,:]
        ds=xr.open_dataset(dir2+'merra2.iwv.3hr.model.'+str(year)+'.nc')
        iwv=ds['iwv'][0::2,:,:]
        ds=xr.open_dataset(dir3+'merra2.u850.6hr.'+str(year)+'.nc')
        u=ds['u']
        ds=xr.open_dataset(dir3+'merra2.v850.6hr.'+str(year)+'.nc')
        v=ds['v']
        s=np.sqrt(u**2+v**2)
        
        ds=xr.open_dataset(dir2+'merra2.mfc.3hr.model.'+str(year)+'.nc')#merra-2 is tendency
        mfc=ds['mfc'][0::2,:,:]
    
    
    ivt['lon']=binary.lon.values
    iwv['lon']=binary.lon.values
    s['lon']=binary.lon.values
    mfc['lon']=binary.lon.values
        
    ivt['lat']=binary.lat.values
    iwv['lat']=binary.lat.values
    s['lat']=binary.lat.values
    mfc['lat']=binary.lat.values
    
    ivt['time']=binary.time.values
    iwv['time']=binary.time.values
    s['time']=binary.time.values
    mfc['time']=binary.time.values
    
    areas['lat']=binary.lat.values
    areas['lon']=binary.lon.values
    
    
    var_sel=ivt.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_merra2lo:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    ivt_list_merra2lo.append(var_mean)
    print(var_mean)


    var_sel=iwv.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_merra2lo:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    iwv_list_merra2lo.append(var_mean)
    print(var_mean)
    
    var_sel=s.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_merra2lo:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    s_list_merra2lo.append(var_mean)
    print(var_mean)
    
    var_sel=mfc.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_merra2lo:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    mfc_list_merra2lo.append(var_mean)
    print(var_mean)
    
    
    ###
    
    ds=xr.open_dataset(dir2+'merra2.ar.cndl.'+str(year)+'.nc')
    ar=ds['ar']
    land_mask_interp=land_mask.interp_like(ar[0,:,:])
    ar=ar.where(land_mask_interp>=0.5)
    binary=ar.where(ar==1)
    
    ivt['lon']=binary.lon.values
    iwv['lon']=binary.lon.values
    s['lon']=binary.lon.values
    mfc['lon']=binary.lon.values
        
    ivt['lat']=binary.lat.values
    iwv['lat']=binary.lat.values
    s['lat']=binary.lat.values
    mfc['lat']=binary.lat.values
    
    ivt['time']=binary.time.values
    iwv['time']=binary.time.values
    s['time']=binary.time.values
    mfc['time']=binary.time.values
    
    areas['lat']=binary.lat.values
    areas['lon']=binary.lon.values
    
    var_sel=ivt.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_merra2cndl:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    ivt_list_merra2cndl.append(var_mean)
    print(var_mean)


    var_sel=iwv.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_merra2cndl:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    iwv_list_merra2cndl.append(var_mean)
    print(var_mean)
    
    
    var_sel=s.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_merra2cndl:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    s_list_merra2cndl.append(var_mean)
    print(var_mean)
    
    
    var_sel=mfc.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_merra2cndl:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    mfc_list_merra2cndl.append(var_mean)
    print(var_mean)
    
    ###
    
    ds=xr.open_dataset(dir2+'merra2.ar.acv2.'+str(year)+'.nc')
    ar=ds['ar']
    land_mask_interp=land_mask.interp_like(ar[0,:,:])
    ar=ar.where(land_mask_interp>=0.5)
    binary=ar.where(ar==1)
    
    ivt['lon']=binary.lon.values
    iwv['lon']=binary.lon.values
    s['lon']=binary.lon.values
    mfc['lon']=binary.lon.values
        
    ivt['lat']=binary.lat.values
    iwv['lat']=binary.lat.values
    s['lat']=binary.lat.values
    mfc['lat']=binary.lat.values
    
    ivt['time']=binary.time.values
    iwv['time']=binary.time.values
    s['time']=binary.time.values
    mfc['time']=binary.time.values
    
    areas['lat']=binary.lat.values
    areas['lon']=binary.lon.values
    
    var_sel=ivt.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_merra2ac:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    ivt_list_merra2ac.append(var_mean)
    print(var_mean)


    var_sel=iwv.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_merra2ac:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    iwv_list_merra2ac.append(var_mean)
    print(var_mean)
    
    
    var_sel=s.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_merra2ac:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    s_list_merra2ac.append(var_mean)
    print(var_mean)
    
    
    var_sel=mfc.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_merra2ac:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    mfc_list_merra2ac.append(var_mean)
    print(var_mean)

# %%
fig=plt.figure(figsize=(12,12))
ax=plt.subplot(1,1,1)
ax.plot(yrs,iwv_list_merra2ac)
plt.show()

# %%
dk=xr.Dataset()
dk['ivt_list_merra2lo']=(('time'),ivt_list_merra2lo)
dk['ivt_list_merra2cndl']=(('time'),ivt_list_merra2cndl)
dk['ivt_list_merra2ac']=(('time'),ivt_list_merra2ac)

dk['iwv_list_merra2lo']=(('time'),iwv_list_merra2lo)
dk['iwv_list_merra2cndl']=(('time'),iwv_list_merra2cndl)
dk['iwv_list_merra2ac']=(('time'),iwv_list_merra2ac)

dk['s_list_merra2lo']=(('time'),s_list_merra2lo)
dk['s_list_merra2cndl']=(('time'),s_list_merra2cndl)
dk['s_list_merra2ac']=(('time'),s_list_merra2ac)

dk['mfc_list_merra2lo']=(('time'),mfc_list_merra2lo)
dk['mfc_list_merra2cndl']=(('time'),mfc_list_merra2cndl)
dk['mfc_list_merra2ac']=(('time'),mfc_list_merra2ac)

dk.coords['time']=yrs

try:
    os.remove(dir_data+'land_synoptic_intercomp_merra2artmip_60.nc')
except OSError:
    pass
dk.to_netcdf(dir_data+'land_synoptic_intercomp_merra2artmip_60.nc',mode='w',format='NETCDF4')

# %%
ds=xr.open_dataset(dir2+'merra2_gridareas.nc')
areas=ds['cell_area']/1e6

ivt_list_era5tp=[]
iwv_list_era5tp=[]
s_list_era5tp=[]
mfc_list_era5tp=[]

ivt_list_era5reid=[]
iwv_list_era5reid=[]
s_list_era5reid=[]
mfc_list_era5reid=[]

ivt_list_era5mk=[]
iwv_list_era5mk=[]
s_list_era5mk=[]
mfc_list_era5mk=[]

yrs=np.arange(1980,2020,1)
for i in range(len(yrs)):
    year=yrs[i]
    print(year)
    
    ds=xr.open_dataset('/Users/ahenny/Downloads/data.nc')
    t2m=ds['t2m'][0,:,:]
    land_mask=t2m/t2m
    land_mask=land_mask.fillna(0)
        
    lon_east=[x for x in land_mask.longitude.values if x>=180.]
    lon_west=[x for x in land_mask.longitude.values if x<180.]
    l_east=land_mask.sel(longitude=lon_east)
    l_west=land_mask.sel(longitude=lon_west)
    l_east['longitude']=[x-360. for x in lon_east]
    land_mask=xr.concat([l_east,l_west],dim='longitude')
        
    dk=xr.Dataset()
    dk['land']=(('lat','lon'),land_mask.values)
    dk.coords['lat']=land_mask.latitude.values
    dk.coords['lon']=land_mask.longitude.values
        
    land_mask=dk['land']
    
    ds=xr.open_dataset(dir2+'era5.ar.tempestlr'+str(year)+'.nc')
    ar=ds['ar']
    #land_mask_interp=land_mask.interp_like(ar[0,:,:])
    #ar=ar.where(land_mask_interp>=0.5)
    binary=ar.where(ar==1)

    if 1==1:
        ds=xr.open_dataset(dir2+'era_5_ivtinterp_'+str(year)+'.nc')
        ivt=ds['ivt'][:,:,:]
        ds=xr.open_dataset(dir2+'era_5_iwvinterp_'+str(year)+'.nc')
        iwv=ds['iwv'][:,:,:]
        ds=xr.open_dataset(dir2+'era_5_u850interp_'+str(year)+'.nc')
        u=ds['u']
        ds=xr.open_dataset(dir2+'era_5_v850interp_'+str(year)+'.nc')
        v=ds['v']
        s=np.sqrt(u**2+v**2)

        ds=xr.open_dataset(dir2+'era_5_mfcinterp_'+str(year)+'.nc')#era5 is divergence
        mfc=ds['mfc'][:,:,:]*-1.
    
    ivt['lon']=binary.lon.values
    iwv['lon']=binary.lon.values
    s['lon']=binary.lon.values
    mfc['lon']=binary.lon.values
        
    ivt['lat']=binary.lat.values
    iwv['lat']=binary.lat.values
    s['lat']=binary.lat.values
    mfc['lat']=binary.lat.values
    
    ivt['time']=binary.time.values
    iwv['time']=binary.time.values
    s['time']=binary.time.values
    mfc['time']=binary.time.values
    
    areas['lat']=binary.lat.values
    areas['lon']=binary.lon.values
    
    
    var_sel=ivt.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    if 1==0:
        fig=plt.figure(figsize=(20,10))
        ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
        ax.pcolormesh(var_sel.lon,var_sel.lat,ivt[0,:,:],vmin=0,vmax=600,cmap=plt.cm.seismic)
        ax.coastlines(resolution='10m')
        plt.show()

        fig=plt.figure(figsize=(20,10))
        ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
        ax.pcolormesh(var_sel.lon,var_sel.lat,var_sel[0,:,:],vmin=0,vmax=600,cmap=plt.cm.seismic)
        ax.coastlines(resolution='10m')
        plt.show()
    
    while sum_area<q1_era5tp:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    ivt_list_era5tp.append(var_mean)
    print(var_mean)


    var_sel=iwv.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    if 1==0:
        fig=plt.figure(figsize=(20,10))
        ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
        ax.pcolormesh(var_sel.lon,var_sel.lat,iwv[0,:,:],vmin=0,vmax=60,cmap=plt.cm.seismic)
        ax.coastlines(resolution='10m')
        plt.show()

        fig=plt.figure(figsize=(20,10))
        ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
        ax.pcolormesh(var_sel.lon,var_sel.lat,var_sel[0,:,:],vmin=0,vmax=60,cmap=plt.cm.seismic)
        ax.coastlines(resolution='10m')
        plt.show()
    
    while sum_area<q1_era5tp:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    iwv_list_era5tp.append(var_mean)
    print(var_mean)
    
    var_sel=s.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    if 1==0:
        fig=plt.figure(figsize=(20,10))
        ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
        ax.pcolormesh(var_sel.lon,var_sel.lat,s[0,:,:],vmin=0,vmax=30,cmap=plt.cm.seismic)
        ax.coastlines(resolution='10m')
        plt.show()

        fig=plt.figure(figsize=(20,10))
        ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
        ax.pcolormesh(var_sel.lon,var_sel.lat,var_sel[0,:,:],vmin=0,vmax=30,cmap=plt.cm.seismic)
        ax.coastlines(resolution='10m')
        plt.show()
        sys.exit()
    
    while sum_area<q1_era5tp:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    s_list_era5tp.append(var_mean)
    print(var_mean)
    
    var_sel=mfc.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_era5tp:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    mfc_list_era5tp.append(var_mean)
    print(var_mean)
    
    
    ###
    
    ds=xr.open_dataset(dir2+'era5.ar.reid500.'+str(year)+'.nc')
    ar=ds['ar']
    #land_mask_interp=land_mask.interp_like(ar[0,:,:])
    #ar=ar.where(land_mask_interp>=0.5)
    binary=ar.where(ar==1)
    
    ivt['lon']=binary.lon.values
    iwv['lon']=binary.lon.values
    s['lon']=binary.lon.values
    mfc['lon']=binary.lon.values
        
    ivt['lat']=binary.lat.values
    iwv['lat']=binary.lat.values
    s['lat']=binary.lat.values
    mfc['lat']=binary.lat.values
    
    ivt['time']=binary.time.values
    iwv['time']=binary.time.values
    s['time']=binary.time.values
    mfc['time']=binary.time.values
    
    areas['lat']=binary.lat.values
    areas['lon']=binary.lon.values
    
    var_sel=ivt.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_era5reid:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    ivt_list_era5reid.append(var_mean)
    print(var_mean)


    var_sel=iwv.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_era5reid:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    iwv_list_era5reid.append(var_mean)
    print(var_mean)
    
    
    var_sel=s.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_era5reid:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    s_list_era5reid.append(var_mean)
    print(var_mean)
    
    
    var_sel=mfc.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_era5reid:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    mfc_list_era5reid.append(var_mean)
    print(var_mean)
    
    ###
    
    ds=xr.open_dataset(dir2+'era5.ar.mundhenkv3.'+str(year)+'.nc')
    ar=ds['ar']
    #land_mask_interp=land_mask.interp_like(ar[0,:,:])
    #ar=ar.where(land_mask_interp>=0.5)
    binary=ar.where(ar==1)
    
    ivt['lon']=binary.lon.values
    iwv['lon']=binary.lon.values
    s['lon']=binary.lon.values
    mfc['lon']=binary.lon.values
        
    ivt['lat']=binary.lat.values
    iwv['lat']=binary.lat.values
    s['lat']=binary.lat.values
    mfc['lat']=binary.lat.values
    
    ivt['time']=binary.time.values
    iwv['time']=binary.time.values
    s['time']=binary.time.values
    mfc['time']=binary.time.values
    
    areas['lat']=binary.lat.values
    areas['lon']=binary.lon.values
    
    var_sel=ivt.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_era5mk:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    ivt_list_era5mk.append(var_mean)
    print(var_mean)


    var_sel=iwv.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_era5mk:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    iwv_list_era5mk.append(var_mean)
    print(var_mean)
    
    
    var_sel=s.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_era5mk:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    s_list_era5mk.append(var_mean)
    print(var_mean)
    
    
    var_sel=mfc.where(binary==1).transpose('time','lat','lon')
    areas_sel=areas.where(binary==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_era5mk:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    mfc_list_era5mk.append(var_mean)
    print(var_mean)

# %%
test=ivt_list_era5tp

fig=plt.figure(figsize=(12,12))
ax=plt.subplot(1,1,1)
ax.plot(yrs,test)

r=st.linregress(yrs,test)
print(r[3])
mean=float(sum(test))/float(len(test))
print(mean)
print(r[0]*40./mean*100.)
plt.show()

# %%
dk=xr.Dataset()
dk['ivt_list_era5tp']=(('time'),ivt_list_era5tp)
dk['ivt_list_era5reid']=(('time'),ivt_list_era5reid)
dk['ivt_list_era5mk']=(('time'),ivt_list_era5mk)

dk['iwv_list_era5tp']=(('time'),iwv_list_era5tp)
dk['iwv_list_era5reid']=(('time'),iwv_list_era5reid)
dk['iwv_list_era5mk']=(('time'),iwv_list_era5mk)

dk['s_list_era5tp']=(('time'),s_list_era5tp)
dk['s_list_era5reid']=(('time'),s_list_era5reid)
dk['s_list_era5mk']=(('time'),s_list_era5mk)

dk['mfc_list_era5tp']=(('time'),mfc_list_era5tp)
dk['mfc_list_era5reid']=(('time'),mfc_list_era5reid)
dk['mfc_list_era5mk']=(('time'),mfc_list_era5mk)

dk.coords['time']=yrs

try:
    os.remove(dir_data+'land_synoptic_intercomp_era5artmip_50_global.nc')
except OSError:
    pass
dk.to_netcdf(dir_data+'land_synoptic_intercomp_era5artmip_50_global.nc',mode='w',format='NETCDF4')

# %%
ds=xr.open_dataset(dir3+'jra55_ivt_'+str(year)+'.nc')
print(ds)

# %%
ds=xr.open_dataset(dir_data+'Downloads/jra55_gridareas_125.nc')
areas=ds['cell_area']/1e6

ivt_list_jra55gw=[]
iwv_list_jra55gw=[]
s_list_jra55gw=[]

yrs=np.arange(1980,2020,1)
for i in range(len(yrs)):
    year=yrs[i]
    print(year)
    
    ds=xr.open_dataset('/Users/ahenny/Downloads/data.nc')
    t2m=ds['t2m'][0,:,:]
    land_mask=t2m/t2m
    land_mask=land_mask.fillna(0)
        
    lon_east=[x for x in land_mask.longitude.values if x>=180.]
    lon_west=[x for x in land_mask.longitude.values if x<180.]
    l_east=land_mask.sel(longitude=lon_east)
    l_west=land_mask.sel(longitude=lon_west)
    l_east['longitude']=[x-360. for x in lon_east]
    land_mask=xr.concat([l_east,l_west],dim='longitude')
        
    dk=xr.Dataset()
    dk['land']=(('lat','lon'),land_mask.values)
    dk.coords['lat']=land_mask.latitude.values
    dk.coords['lon']=land_mask.longitude.values
        
    land_mask=dk['land']
    ds=xr.open_dataset(dir2+'jra55.ar.gwv2.'+str(year)+'.nc')
    ar=ds['ar']
    
    ds=xr.open_dataset(dir3+'jra55_ivt_'+str(year)+'.nc')
    ivt=ds['ivt'].interp(lat=ar.lat.values,lon=ar.lon.values)
    ds=xr.open_dataset(dir3+'jra55_iwv_'+str(year)+'.nc')
    iwv=ds['iwv'].interp(lat=ar.lat.values,lon=ar.lon.values)
    ds=xr.open_dataset(dir3+'jra55_u850_'+str(year)+'.nc')
    u=ds['u'].interp(lat=ar.lat.values,lon=ar.lon.values)
    ds=xr.open_dataset(dir3+'jra55_v850_'+str(year)+'.nc')
    v=ds['v'].interp(lat=ar.lat.values,lon=ar.lon.values)
    s=np.sqrt(u**2+v**2)
        
    land_mask_interp=land_mask.interp_like(ar[0,:,:])
    ar=ar.where(land_mask_interp>=0.5)
    
    areas['lat']=ar.lat.values
    areas['lon']=ar.lon.values
    
    ivt['lon']=ar.lon.values
    iwv['lon']=ar.lon.values
    s['lon']=ar.lon.values
    #mfc['lon']=ar.lon.values
        
    ivt['lat']=ar.lat.values
    iwv['lat']=ar.lat.values
    s['lat']=ar.lat.values
    #mfc['lat']=ar.lat.values
    
    ivt['time']=ar.time.values
    iwv['time']=ar.time.values
    s['time']=ar.time.values
    #mfc['time']=ar.time.values

    var_sel=ivt.where(ar==1).transpose('time','lat','lon')
    areas_sel=areas.where(ar==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_jra55gw:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    ivt_list_jra55gw.append(var_mean)
    print(var_mean)


    var_sel=iwv.where(ar==1).transpose('time','lat','lon')
    areas_sel=areas.where(ar==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_jra55gw:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    iwv_list_jra55gw.append(var_mean)
    print(var_mean)
    
    var_sel=s.where(ar==1).transpose('time','lat','lon')
    areas_sel=areas.where(ar==1).transpose('time','lat','lon')
    var_list=var_sel.values.ravel()
    areas_list=areas_sel.values.ravel()
    var_list=var_list[~np.isnan(var_list)]
    area_list=areas_list[~np.isnan(areas_list)]
    zipped=list(zip(area_list,var_list))
    sort=sorted(zipped,key=lambda x:x[1])
    sum_area=0
    j=0
    
    while sum_area<q1_jra55gw:
        sum_area=sum_area+sort[-1*(j+1)][0]
        j=j+1
        index_final=j
    
    threshold=sort[-1*index_final][1]
    var_filter=var_sel.where(var_sel>=threshold)
    weights=np.cos(np.deg2rad(var_sel.lat))
    weighted=var_filter.weighted(weights)
    var_mean=weighted.mean().values.tolist()
    s_list_jra55gw.append(var_mean)
    print(var_mean)

# %%
fig=plt.figure(figsize=(20,10))
ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
ax.pcolormesh(var_sel.lon,var_sel.lat,var_sel[80,:,:],vmin=0,vmax=30,cmap=plt.cm.seismic)
ax.coastlines(resolution='10m')
plt.show()

fig=plt.figure(figsize=(20,10))
ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
ax.pcolormesh(var_sel.lon,var_sel.lat,var_filter[80,:,:],vmin=0,vmax=30,cmap=plt.cm.seismic)
ax.coastlines(resolution='10m')
plt.show()


fig=plt.figure(figsize=(20,10))
ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
ax.pcolormesh(var_sel.lon,var_sel.lat,s[80,:,:],vmin=0,vmax=30,cmap=plt.cm.seismic)
ax.coastlines(resolution='10m')
plt.show()

fig=plt.figure(figsize=(20,10))
ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
ax.pcolormesh(var_sel.lon,var_sel.lat,ar[80,:,:],vmin=0,vmax=1,cmap=plt.cm.seismic)
ax.coastlines(resolution='10m')
plt.show()


fig=plt.figure(figsize=(20,10))
ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
ax.pcolormesh(var_sel.lon,var_sel.lat,ivt[80,:,:],vmin=0,vmax=300,cmap=plt.cm.seismic)
ax.coastlines(resolution='10m')
plt.show()

# %%
fig=plt.figure(figsize=(12,12))
ax=plt.subplot(1,1,1)
ax.plot(yrs,ivt_list_jra55gw)
plt.show()

# %%
dk=xr.Dataset()
dk['ivt_list_jra55gw']=(('time'),ivt_list_jra55gw)
dk['iwv_list_jra55gw']=(('time'),iwv_list_jra55gw)
dk['s_list_jra55gw']=(('time'),s_list_jra55gw)

dk.coords['time']=yrs

try:
    os.remove(dir_data+'land_synoptic_intercomp_jra55artmip_25.nc')
except OSError:
    pass
dk.to_netcdf(dir_data+'land_synoptic_intercomp_jra55artmip_25.nc',mode='w',format='NETCDF4')
