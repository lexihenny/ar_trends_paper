# %%
import numpy as np
import xarray as xr
import os,errno
import sys
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
import salem
import scipy.stats as st
import cartopy.crs as ccrs

dir_data='/Users/ahenny/'
dir2='/Volumes/Extreme Pro/'
dir3='/Volumes/My Passport/'

# %%
ds=xr.open_dataset(dir_data+'ar_chars_synoptic_merra2_LAND.nc')#_LAND

try:
    ivt_array_merra2_variable=ds['ivt_array_merra2_polar'].values
    ivt_max_array_merra2_variable=ds['ivt_max_array_merra2_polar'].values
    iwv_array_merra2_variable=ds['iwv_array_merra2_polar'].values
    iwv_max_array_merra2_variable=ds['iwv_max_array_merra2_polar'].values
    s_array_merra2_variable=ds['s_array_merra2_polar'].values
    s_max_array_merra2_variable=ds['s_max_array_merra2_polar'].values
    mfc_array_merra2_variable=ds['mfc_array_merra2_polar'].values
    mfc_max_array_merra2_variable=ds['mfc_max_array_merra2_polar'].values
except:
    ivt_array_merra2_variable=ds['ivt_array_merra2_variable'].values
    ivt_max_array_merra2_variable=ds['ivt_max_array_merra2_variable'].values
    iwv_array_merra2_variable=ds['iwv_array_merra2_variable'].values
    iwv_max_array_merra2_variable=ds['iwv_max_array_merra2_variable'].values
    s_array_merra2_variable=ds['s_array_merra2_variable'].values
    s_max_array_merra2_variable=ds['s_max_array_merra2_variable'].values
    mfc_array_merra2_variable=ds['mfc_array_merra2_variable'].values
    mfc_max_array_merra2_variable=ds['mfc_max_array_merra2_variable'].values
    
ivt_array_merra2_fixed=ds['ivt_array_merra2_fixed'].values
ivt_max_array_merra2_fixed=ds['ivt_max_array_merra2_fixed'].values
iwv_array_merra2_fixed=ds['iwv_array_merra2_fixed'].values
iwv_max_array_merra2_fixed=ds['iwv_max_array_merra2_fixed'].values
s_array_merra2_fixed=ds['s_array_merra2_fixed'].values
s_max_array_merra2_fixed=ds['s_max_array_merra2_fixed'].values
mfc_array_merra2_fixed=ds['mfc_array_merra2_fixed'].values
mfc_max_array_merra2_fixed=ds['mfc_max_array_merra2_fixed'].values

ivt_list_merra2_fixed=ds['ivt_list_merra2_fixed'].values.tolist()
ivt_max_list_merra2_fixed=ds['ivt_max_list_merra2_fixed'].values.tolist()
iwv_list_merra2_fixed=ds['iwv_list_merra2_fixed'].values.tolist()
iwv_max_list_merra2_fixed=ds['iwv_max_list_merra2_fixed'].values.tolist()
s_list_merra2_fixed=ds['s_list_merra2_fixed'].values.tolist()
s_max_list_merra2_fixed=ds['s_max_list_merra2_fixed'].values.tolist()
mfc_list_merra2_fixed=ds['mfc_list_merra2_fixed'].values.tolist()
mfc_max_list_merra2_fixed=ds['mfc_max_list_merra2_fixed'].values.tolist()

try:
    ivt_list_merra2_variable=ds['ivt_list_merra2_polar'].values.tolist()
    ivt_max_list_merra2_variable=ds['ivt_max_list_merra2_polar'].values.tolist()
    iwv_list_merra2_variable=ds['iwv_list_merra2_polar'].values.tolist()
    iwv_max_list_merra2_variable=ds['iwv_max_list_merra2_polar'].values.tolist()
    s_list_merra2_variable=ds['s_list_merra2_polar'].values.tolist()
    s_max_list_merra2_variable=ds['s_max_list_merra2_polar'].values.tolist()
    mfc_list_merra2_variable=ds['mfc_list_merra2_polar'].values.tolist()
    mfc_max_list_merra2_variable=ds['mfc_max_list_merra2_polar'].values.tolist()
except:
    ivt_list_merra2_variable=ds['ivt_list_merra2_variable'].values.tolist()
    ivt_max_list_merra2_variable=ds['ivt_max_list_merra2_variable'].values.tolist()
    iwv_list_merra2_variable=ds['iwv_list_merra2_variable'].values.tolist()
    iwv_max_list_merra2_variable=ds['iwv_max_list_merra2_variable'].values.tolist()
    s_list_merra2_variable=ds['s_list_merra2_variable'].values.tolist()
    s_max_list_merra2_variable=ds['s_max_list_merra2_variable'].values.tolist()
    mfc_list_merra2_variable=ds['mfc_list_merra2_variable'].values.tolist()
    mfc_max_list_merra2_variable=ds['mfc_max_list_merra2_variable'].values.tolist()

ivt_array_merra2_fixed_poleward=ds['ivt_array_merra2_fixed_poleward']
ivt_max_array_merra2_fixed_poleward=ds['ivt_max_array_merra2_fixed_poleward']
iwv_array_merra2_fixed_poleward=ds['iwv_array_merra2_fixed_poleward']
iwv_max_array_merra2_fixed_poleward=ds['iwv_max_array_merra2_fixed_poleward']
s_array_merra2_fixed_poleward=ds['s_array_merra2_fixed_poleward']
s_max_array_merra2_fixed_poleward=ds['s_max_array_merra2_fixed_poleward']
mfc_array_merra2_fixed_poleward=ds['mfc_array_merra2_fixed_poleward']
mfc_max_array_merra2_fixed_poleward=ds['mfc_max_array_merra2_fixed_poleward']

ivt_list_merra2_fixed_poleward=ds['ivt_list_merra2_fixed_poleward'].values
ivt_max_list_merra2_fixed_poleward=ds['ivt_max_list_merra2_fixed_poleward'].values
iwv_list_merra2_fixed_poleward=ds['iwv_list_merra2_fixed_poleward'].values
iwv_max_list_merra2_fixed_poleward=ds['iwv_max_list_merra2_fixed_poleward'].values
s_list_merra2_fixed_poleward=ds['s_list_merra2_fixed_poleward'].values
s_max_list_merra2_fixed_poleward=ds['s_max_list_merra2_fixed_poleward'].values
mfc_list_merra2_fixed_poleward=ds['mfc_list_merra2_fixed_poleward'].values
mfc_max_list_merra2_fixed_poleward=ds['mfc_max_list_merra2_fixed_poleward'].values

ds=xr.open_dataset(dir_data+'ar_chars_synoptic_era5_LAND.nc')

try:
    ivt_array_era5_variable=ds['ivt_array_era5_polar'].values
    ivt_max_array_era5_variable=ds['ivt_max_array_era5_polar'].values
    iwv_array_era5_variable=ds['iwv_array_era5_polar'].values
    iwv_max_array_era5_variable=ds['iwv_max_array_era5_polar'].values
    s_array_era5_variable=ds['s_array_era5_polar'].values
    s_max_array_era5_variable=ds['s_max_array_era5_polar'].values
    mfc_array_era5_variable=ds['mfc_array_era5_polar'].values
    mfc_max_array_era5_variable=ds['mfc_max_array_era5_polar'].values
    #mfc_sum_array_era5_polar=ds['mfc_sum_array_era5_polar'].values

    ivt_list_era5_variable=ds['ivt_list_era5_polar'].values.tolist()
    ivt_max_list_era5_variable=ds['ivt_max_list_era5_polar'].values.tolist()
    iwv_list_era5_variable=ds['iwv_list_era5_polar'].values.tolist()
    iwv_max_list_era5_variable=ds['iwv_max_list_era5_polar'].values.tolist()
    s_list_era5_variable=ds['s_list_era5_polar'].values.tolist()
    s_max_list_era5_variable=ds['s_max_list_era5_polar'].values.tolist()
    mfc_list_era5_variable=ds['mfc_list_era5_polar'].values.tolist()
    mfc_max_list_era5_variable=ds['mfc_max_list_era5_polar'].values.tolist()
    #mfc_sum_list_era5_polar=ds['mfc_sum_list_era5_polar'].values.tolist()
except:
    ivt_array_era5_variable=ds['ivt_array_era5_variable'].values
    ivt_max_array_era5_variable=ds['ivt_max_array_era5_variable'].values
    iwv_array_era5_variable=ds['iwv_array_era5_variable'].values
    iwv_max_array_era5_variable=ds['iwv_max_array_era5_variable'].values
    s_array_era5_variable=ds['s_array_era5_variable'].values
    s_max_array_era5_variable=ds['s_max_array_era5_variable'].values
    mfc_array_era5_variable=ds['mfc_array_era5_variable'].values
    mfc_max_array_era5_variable=ds['mfc_max_array_era5_variable'].values
    #mfc_sum_array_era5_polar=ds['mfc_sum_array_era5_polar'].values

    ivt_list_era5_variable=ds['ivt_list_era5_variable'].values.tolist()
    ivt_max_list_era5_variable=ds['ivt_max_list_era5_variable'].values.tolist()
    iwv_list_era5_variable=ds['iwv_list_era5_variable'].values.tolist()
    iwv_max_list_era5_variable=ds['iwv_max_list_era5_variable'].values.tolist()
    s_list_era5_variable=ds['s_list_era5_variable'].values.tolist()
    s_max_list_era5_variable=ds['s_max_list_era5_variable'].values.tolist()
    mfc_list_era5_variable=ds['mfc_list_era5_variable'].values.tolist()
    mfc_max_list_era5_variable=ds['mfc_max_list_era5_variable'].values.tolist()
    #mfc_sum_list_era5_polar=ds['mfc_sum_list_era5_polar'].values.tolist()

ivt_array_era5_fixed=ds['ivt_array_era5_fixed'].values
ivt_max_array_era5_fixed=ds['ivt_max_array_era5_fixed'].values
iwv_array_era5_fixed=ds['iwv_array_era5_fixed'].values
iwv_max_array_era5_fixed=ds['iwv_max_array_era5_fixed'].values
s_array_era5_fixed=ds['s_array_era5_fixed'].values
s_max_array_era5_fixed=ds['s_max_array_era5_fixed'].values
mfc_array_era5_fixed=ds['mfc_array_era5_fixed'].values
mfc_max_array_era5_fixed=ds['mfc_max_array_era5_fixed'].values
#mfc_sum_array_era5_fixed=ds['mfc_sum_array_era5_fixed'].values

ivt_array_era5_fixed_poleward=ds['ivt_array_era5_fixed_poleward'].values
ivt_max_array_era5_fixed_poleward=ds['ivt_max_array_era5_fixed_poleward'].values
iwv_array_era5_fixed_poleward=ds['iwv_array_era5_fixed_poleward'].values
iwv_max_array_era5_fixed_poleward=ds['iwv_max_array_era5_fixed_poleward'].values
s_array_era5_fixed_poleward=ds['s_array_era5_fixed_poleward'].values
s_max_array_era5_fixed_poleward=ds['s_max_array_era5_fixed_poleward'].values
mfc_array_era5_fixed_poleward=ds['mfc_array_era5_fixed_poleward'].values
mfc_max_array_era5_fixed_poleward=ds['mfc_max_array_era5_fixed_poleward'].values
#mfc_sum_array_era5_fixed_poleward=ds['mfc_sum_array_era5_fixed_poleward'].values

ivt_list_era5_fixed=ds['ivt_list_era5_fixed'].values.tolist()
ivt_max_list_era5_fixed=ds['ivt_max_list_era5_fixed'].values.tolist()
iwv_list_era5_fixed=ds['iwv_list_era5_fixed'].values.tolist()
iwv_max_list_era5_fixed=ds['iwv_max_list_era5_fixed'].values.tolist()
s_list_era5_fixed=ds['s_list_era5_fixed'].values.tolist()
s_max_list_era5_fixed=ds['s_max_list_era5_fixed'].values.tolist()
mfc_list_era5_fixed=ds['mfc_list_era5_fixed'].values.tolist()
mfc_max_list_era5_fixed=ds['mfc_max_list_era5_fixed'].values.tolist()
#mfc_sum_list_era5_fixed=ds['mfc_sum_list_era5_fixed'].values.tolist()

ivt_list_era5_fixed_poleward=ds['ivt_list_era5_fixed_poleward'].values.tolist()
ivt_max_list_era5_fixed_poleward=ds['ivt_max_list_era5_fixed_poleward'].values.tolist()
iwv_list_era5_fixed_poleward=ds['iwv_list_era5_fixed_poleward'].values.tolist()
iwv_max_list_era5_fixed_poleward=ds['iwv_max_list_era5_fixed_poleward'].values.tolist()
s_list_era5_fixed_poleward=ds['s_list_era5_fixed_poleward'].values.tolist()
s_max_list_era5_fixed_poleward=ds['s_max_list_era5_fixed_poleward'].values.tolist()
mfc_list_era5_fixed_poleward=ds['mfc_list_era5_fixed_poleward'].values.tolist()
mfc_max_list_era5_fixed_poleward=ds['mfc_max_list_era5_fixed_poleward'].values.tolist()
#mfc_sum_list_era5_fixed_poleward=ds['mfc_sum_list_era5_fixed_poleward'].values.tolist()


ds=xr.open_dataset(dir_data+'ar_chars_synoptic_jra55_LAND.nc')

try:
    ivt_array_jra55_variable=ds['ivt_array_jra55_polar'].values
    ivt_max_array_jra55_variable=ds['ivt_max_array_jra55_polar'].values
    iwv_array_jra55_variable=ds['iwv_array_jra55_polar'].values
    iwv_max_array_jra55_variable=ds['iwv_max_array_jra55_polar'].values
    s_array_jra55_variable=ds['s_array_jra55_polar'].values
    s_max_array_jra55_variable=ds['s_max_array_jra55_polar'].values
    #mfc_array_jra55_polar=ds['mfc_array_jra55_polar'].values
    #mfc_max_array_jra55_polar=ds['mfc_max_array_jra55_polar'].values

    ivt_list_jra55_variable=ds['ivt_list_jra55_polar'].values.tolist()
    ivt_max_list_jra55_variable=ds['ivt_max_list_jra55_polar'].values.tolist()
    iwv_list_jra55_variable=ds['iwv_list_jra55_polar'].values.tolist()
    iwv_max_list_jra55_variable=ds['iwv_max_list_jra55_polar'].values.tolist()
    s_list_jra55_variable=ds['s_list_jra55_polar'].values.tolist()
    s_max_list_jra55_variable=ds['s_max_list_jra55_polar'].values.tolist()
    #mfc_list_era5_polar=ds['mfc_list_era5_polar'].values.tolist()
    #mfc_max_list_era5_polar=ds['mfc_max_list_era5_polar'].values.tolist()
except:
    ivt_array_jra55_variable=ds['ivt_array_jra55_variable'].values
    ivt_max_array_jra55_variable=ds['ivt_max_array_jra55_variable'].values
    iwv_array_jra55_variable=ds['iwv_array_jra55_variable'].values
    iwv_max_array_jra55_variable=ds['iwv_max_array_jra55_variable'].values
    s_array_jra55_variable=ds['s_array_jra55_variable'].values
    s_max_array_jra55_variable=ds['s_max_array_jra55_variable'].values
    #mfc_array_jra55_polar=ds['mfc_array_jra55_polar'].values
    #mfc_max_array_jra55_polar=ds['mfc_max_array_jra55_polar'].values

    ivt_list_jra55_variable=ds['ivt_list_jra55_variable'].values.tolist()
    ivt_max_list_jra55_variable=ds['ivt_max_list_jra55_variable'].values.tolist()
    iwv_list_jra55_variable=ds['iwv_list_jra55_variable'].values.tolist()
    iwv_max_list_jra55_variable=ds['iwv_max_list_jra55_variable'].values.tolist()
    s_list_jra55_variable=ds['s_list_jra55_variable'].values.tolist()
    s_max_list_jra55_variable=ds['s_max_list_jra55_variable'].values.tolist()
    #mfc_list_era5_polar=ds['mfc_list_era5_polar'].values.tolist()
    #mfc_max_list_era5_polar=ds['mfc_max_list_era5_polar'].values.tolist()

ivt_array_jra55_fixed=ds['ivt_array_jra55_fixed'].values
ivt_max_array_jra55_fixed=ds['ivt_max_array_jra55_fixed'].values
iwv_array_jra55_fixed=ds['iwv_array_jra55_fixed'].values
iwv_max_array_jra55_fixed=ds['iwv_max_array_jra55_fixed'].values
s_array_jra55_fixed=ds['s_array_jra55_fixed'].values
s_max_array_jra55_fixed=ds['s_max_array_jra55_fixed'].values
#mfc_array_era5_fixed=ds['mfc_array_era5_fixed'].values
#mfc_max_array_era5_fixed=ds['mfc_max_array_era5_fixed'].values

ivt_array_jra55_fixed_poleward=ds['ivt_array_jra55_fixed_poleward'].values
ivt_max_array_jra55_fixed_poleward=ds['ivt_max_array_jra55_fixed_poleward'].values
iwv_array_jra55_fixed_poleward=ds['iwv_array_jra55_fixed_poleward'].values
iwv_max_array_jra55_fixed_poleward=ds['iwv_max_array_jra55_fixed_poleward'].values
s_array_jra55_fixed_poleward=ds['s_array_jra55_fixed_poleward'].values
s_max_array_jra55_fixed_poleward=ds['s_max_array_jra55_fixed_poleward'].values
#mfc_array_era5_fixed_poleward=ds['mfc_array_era5_fixed_poleward'].values
#mfc_max_array_era5_fixed_poleward=ds['mfc_max_array_era5_fixed_poleward'].values

ivt_list_jra55_fixed=ds['ivt_list_jra55_fixed'].values.tolist()
ivt_max_list_jra55_fixed=ds['ivt_max_list_jra55_fixed'].values.tolist()
iwv_list_jra55_fixed=ds['iwv_list_jra55_fixed'].values.tolist()
iwv_max_list_jra55_fixed=ds['iwv_max_list_jra55_fixed'].values.tolist()
s_list_jra55_fixed=ds['s_list_jra55_fixed'].values.tolist()
s_max_list_jra55_fixed=ds['s_max_list_jra55_fixed'].values.tolist()
#mfc_list_era5_fixed=ds['mfc_list_era5_fixed'].values.tolist()
#mfc_max_list_era5_fixed=ds['mfc_max_list_era5_fixed'].values.tolist()

ivt_list_jra55_fixed_poleward=ds['ivt_list_jra55_fixed_poleward'].values.tolist()
ivt_max_list_jra55_fixed_poleward=ds['ivt_max_list_jra55_fixed_poleward'].values.tolist()
iwv_list_jra55_fixed_poleward=ds['iwv_list_jra55_fixed_poleward'].values.tolist()
iwv_max_list_jra55_fixed_poleward=ds['iwv_max_list_jra55_fixed_poleward'].values.tolist()
s_list_jra55_fixed_poleward=ds['s_list_jra55_fixed_poleward'].values.tolist()
s_max_list_jra55_fixed_poleward=ds['s_max_list_jra55_fixed_poleward'].values.tolist()
#mfc_list_era5_fixed_poleward=ds['mfc_list_era5_fixed_poleward'].values.tolist()
#mfc_max_list_era5_fixed_poleward=ds['mfc_max_list_era5_fixed_poleward'].values.tolist()

# %%
yrs=np.arange(1980,2024,1)
yrs1=np.arange(1940,2024,1)
yrs2=np.arange(1958,2024,1)

sigs_list=[]

fig=plt.figure(figsize=(15,15))
ax=plt.subplot(1,1,1)

ax.fill_between([1939,1979.5],-10,10,color='gray',alpha=0.4)

count=0
test=ivt_list_era5_variable[40:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=ivt_list_era5_variable
mean=float(sum(test))/float(len(test))
ivt_list_era5_variable_percent=[(x/mean-1.)*100. for x in test]
 
test=ivt_list_era5_fixed[40:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=ivt_list_era5_fixed
mean=float(sum(test))/float(len(test))
ivt_list_era5_fixed_percent=[(x/mean-1.)*100. for x in test]

test=ivt_list_era5_fixed_poleward[40:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=ivt_list_era5_fixed_poleward
mean=float(sum(test))/float(len(test))
ivt_list_era5_fixed_poleward_percent=[(x/mean-1.)*100. for x in test]
    

test=ivt_list_jra55_variable[22:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=ivt_list_jra55_variable
mean=float(sum(test))/float(len(test))
ivt_list_jra55_variable_percent=[(x/mean-1.)*100. for x in test]
 
test=ivt_list_jra55_fixed[22:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=ivt_list_jra55_fixed
mean=float(sum(test))/float(len(test))
ivt_list_jra55_fixed_percent=[(x/mean-1.)*100. for x in test]

test=ivt_list_jra55_fixed_poleward[22:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=ivt_list_jra55_fixed_poleward
mean=float(sum(test))/float(len(test))
ivt_list_jra55_fixed_poleward_percent=[(x/mean-1.)*100. for x in test]


test=ivt_list_merra2_variable
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=ivt_list_merra2_variable
mean=float(sum(test))/float(len(test))
ivt_list_merra2_variable_percent=[(x/mean-1.)*100. for x in test]

test=ivt_list_merra2_fixed
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=ivt_list_merra2_fixed
mean=float(sum(test))/float(len(test))
ivt_list_merra2_fixed_percent=[(x/mean-1.)*100. for x in test]

test=ivt_list_merra2_fixed_poleward
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=ivt_list_merra2_fixed_poleward
mean=float(sum(test))/float(len(test))
ivt_list_merra2_fixed_poleward_percent=[(x/mean-1.)*100. for x in test]


test_array=np.zeros((9,84))
testa=[np.nan]*40+ivt_list_merra2_fixed_percent
testb=[np.nan]*40+ivt_list_merra2_fixed_poleward_percent
testc=[np.nan]*40+ivt_list_merra2_variable_percent

testa1=[np.nan]*18+ivt_list_jra55_fixed_percent
testb1=[np.nan]*18+ivt_list_jra55_fixed_poleward_percent
testc1=[np.nan]*18+ivt_list_jra55_variable_percent

testa2=ivt_list_era5_fixed_percent
testb2=ivt_list_era5_fixed_poleward_percent
testc2=ivt_list_era5_variable_percent

test_array[0,:]=testa
test_array[1,:]=testb
test_array[2,:]=testc
test_array[3,:]=testa1
test_array[4,:]=testb1
test_array[5,:]=testc1
test_array[6,:]=testa2
test_array[7,:]=testb2
test_array[8,:]=testc2

avg_value=np.nanmean(test_array,axis=0)
min_value=np.nanmin(test_array,axis=0)
max_value=np.nanmax(test_array,axis=0)
    
label='Within-AR mean IVT, '+str(count)+' significant'
ax.plot(yrs1,avg_value,color='k',linewidth=10,label=label)
ax.fill_between(yrs1,min_value,max_value,color='gray',alpha=0.6)


#####

count=0
test=ivt_max_list_era5_variable[40:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=ivt_max_list_era5_variable
mean=float(sum(test))/float(len(test))
ivt_max_list_era5_variable_percent=[(x/mean-1.)*100. for x in test]
 
test=ivt_max_list_era5_fixed[40:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=ivt_max_list_era5_fixed
mean=float(sum(test))/float(len(test))
ivt_max_list_era5_fixed_percent=[(x/mean-1.)*100. for x in test]

test=ivt_max_list_era5_fixed_poleward[40:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=ivt_max_list_era5_fixed_poleward
mean=float(sum(test))/float(len(test))
ivt_max_list_era5_fixed_poleward_percent=[(x/mean-1.)*100. for x in test]
    

test=ivt_max_list_jra55_variable[22:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=ivt_max_list_jra55_variable
mean=float(sum(test))/float(len(test))
ivt_max_list_jra55_variable_percent=[(x/mean-1.)*100. for x in test]
 
test=ivt_max_list_jra55_fixed[22:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=ivt_max_list_jra55_fixed
mean=float(sum(test))/float(len(test))
ivt_max_list_jra55_fixed_percent=[(x/mean-1.)*100. for x in test]

test=ivt_max_list_jra55_fixed_poleward[22:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=ivt_max_list_jra55_fixed_poleward
mean=float(sum(test))/float(len(test))
ivt_max_list_jra55_fixed_poleward_percent=[(x/mean-1.)*100. for x in test]


test=ivt_max_list_merra2_variable
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=ivt_max_list_merra2_variable
mean=float(sum(test))/float(len(test))
ivt_max_list_merra2_variable_percent=[(x/mean-1.)*100. for x in test]

test=ivt_max_list_merra2_fixed
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=ivt_max_list_merra2_fixed
mean=float(sum(test))/float(len(test))
ivt_max_list_merra2_fixed_percent=[(x/mean-1.)*100. for x in test]

test=ivt_max_list_merra2_fixed_poleward
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=ivt_max_list_merra2_fixed_poleward
mean=float(sum(test))/float(len(test))
ivt_max_list_merra2_fixed_poleward_percent=[(x/mean-1.)*100. for x in test]


test_array=np.zeros((9,84))
testa=[np.nan]*40+ivt_max_list_merra2_fixed_percent
testb=[np.nan]*40+ivt_max_list_merra2_fixed_poleward_percent
testc=[np.nan]*40+ivt_max_list_merra2_variable_percent

testa1=[np.nan]*18+ivt_max_list_jra55_fixed_percent
testb1=[np.nan]*18+ivt_max_list_jra55_fixed_poleward_percent
testc1=[np.nan]*18+ivt_max_list_jra55_variable_percent

testa2=ivt_max_list_era5_fixed_percent
testb2=ivt_max_list_era5_fixed_poleward_percent
testc2=ivt_max_list_era5_variable_percent

test_array[0,:]=testa
test_array[1,:]=testb
test_array[2,:]=testc
test_array[3,:]=testa1
test_array[4,:]=testb1
test_array[5,:]=testc1
test_array[6,:]=testa2
test_array[7,:]=testb2
test_array[8,:]=testc2

avg_value=np.nanmean(test_array,axis=0)
min_value=np.nanmin(test_array,axis=0)
max_value=np.nanmax(test_array,axis=0)
    
label='Within-AR maximum IVT, '+str(count)+' significant'
ax.plot(yrs1,avg_value,color='darkred',linewidth=10,label=label)
ax.fill_between(yrs1,min_value,max_value,color='r',alpha=0.6)



ax.tick_params(labelsize=40)
ax.set_xlabel('Year',fontsize=44)
ax.set_ylabel('% anomaly',fontsize=44)
ax.set_title(r'$\bf{AR}$'+' '+r'$\bf{IVT}$'+' '+r'$\bf{land}$',fontsize=61,pad=5)
ax.grid(True,linewidth=2)
plt.legend(loc='upper center',fontsize=36,ncol=1)
ax.set_xlim(1939.3,2023.6)
ax.set_ylim(-8.5,8.5)
ax.set_yticks(np.arange(-6,8,2))
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2.25)

plt.axhline(y=0,linestyle='--',color='k',alpha=0.75,linewidth=3)
plt.show()

# %%
fig.savefig(dir_data+'ar_test1.png')

# %%
yrs=np.arange(1980,2024,1)
yrs1=np.arange(1940,2024,1)
yrs2=np.arange(1958,2024,1)


fig=plt.figure(figsize=(15,15))
ax=plt.subplot(1,1,1)

ax.fill_between([1939,1979.5],-10,10,color='gray',alpha=0.4)

count=0
test=iwv_list_era5_variable[40:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=iwv_list_era5_variable
mean=float(sum(test))/float(len(test))
iwv_list_era5_variable_percent=[(x/mean-1.)*100. for x in test]
 
test=iwv_list_era5_fixed[40:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=iwv_list_era5_fixed
mean=float(sum(test))/float(len(test))
iwv_list_era5_fixed_percent=[(x/mean-1.)*100. for x in test]

test=iwv_list_era5_fixed_poleward[40:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=iwv_list_era5_fixed_poleward
mean=float(sum(test))/float(len(test))
iwv_list_era5_fixed_poleward_percent=[(x/mean-1.)*100. for x in test]
    

test=iwv_list_jra55_variable[22:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=iwv_list_jra55_variable
mean=float(sum(test))/float(len(test))
iwv_list_jra55_variable_percent=[(x/mean-1.)*100. for x in test]
 
test=iwv_list_jra55_fixed[22:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=iwv_list_jra55_fixed
mean=float(sum(test))/float(len(test))
iwv_list_jra55_fixed_percent=[(x/mean-1.)*100. for x in test]

test=iwv_list_jra55_fixed_poleward[22:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=iwv_list_jra55_fixed_poleward
mean=float(sum(test))/float(len(test))
iwv_list_jra55_fixed_poleward_percent=[(x/mean-1.)*100. for x in test]


test=iwv_list_merra2_variable
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=iwv_list_merra2_variable
mean=float(sum(test))/float(len(test))
iwv_list_merra2_variable_percent=[(x/mean-1.)*100. for x in test]

test=iwv_list_merra2_fixed
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=iwv_list_merra2_fixed
mean=float(sum(test))/float(len(test))
iwv_list_merra2_fixed_percent=[(x/mean-1.)*100. for x in test]

test=iwv_list_merra2_fixed_poleward
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=iwv_list_merra2_fixed_poleward
mean=float(sum(test))/float(len(test))
iwv_list_merra2_fixed_poleward_percent=[(x/mean-1.)*100. for x in test]


test_array=np.zeros((9,84))
testa=[np.nan]*40+iwv_list_merra2_fixed_percent
testb=[np.nan]*40+iwv_list_merra2_fixed_poleward_percent
testc=[np.nan]*40+iwv_list_merra2_variable_percent

testa1=[np.nan]*18+iwv_list_jra55_fixed_percent
testb1=[np.nan]*18+iwv_list_jra55_fixed_poleward_percent
testc1=[np.nan]*18+iwv_list_jra55_variable_percent

testa2=iwv_list_era5_fixed_percent
testb2=iwv_list_era5_fixed_poleward_percent
testc2=iwv_list_era5_variable_percent

test_array[0,:]=testa
test_array[1,:]=testb
test_array[2,:]=testc
test_array[3,:]=testa1
test_array[4,:]=testb1
test_array[5,:]=testc1
test_array[6,:]=testa2
test_array[7,:]=testb2
test_array[8,:]=testc2

avg_value=np.nanmean(test_array,axis=0)
min_value=np.nanmin(test_array,axis=0)
max_value=np.nanmax(test_array,axis=0)
    
label='Within-AR mean IWV, '+str(count)+' significant'
ax.plot(yrs1,avg_value,color='k',linewidth=10,label=label)
ax.fill_between(yrs1,min_value,max_value,color='gray',alpha=0.6)


#####

count=0
test=iwv_max_list_era5_variable[40:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=iwv_max_list_era5_variable
mean=float(sum(test))/float(len(test))
iwv_max_list_era5_variable_percent=[(x/mean-1.)*100. for x in test]
 
test=iwv_max_list_era5_fixed[40:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=iwv_max_list_era5_fixed
mean=float(sum(test))/float(len(test))
iwv_max_list_era5_fixed_percent=[(x/mean-1.)*100. for x in test]

test=iwv_max_list_era5_fixed_poleward[40:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=iwv_max_list_era5_fixed_poleward
mean=float(sum(test))/float(len(test))
iwv_max_list_era5_fixed_poleward_percent=[(x/mean-1.)*100. for x in test]
    

test=iwv_max_list_jra55_variable[22:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=iwv_max_list_jra55_variable
mean=float(sum(test))/float(len(test))
iwv_max_list_jra55_variable_percent=[(x/mean-1.)*100. for x in test]
 
test=iwv_max_list_jra55_fixed[22:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=iwv_max_list_jra55_fixed
mean=float(sum(test))/float(len(test))
iwv_max_list_jra55_fixed_percent=[(x/mean-1.)*100. for x in test]

test=iwv_max_list_jra55_fixed_poleward[22:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=iwv_max_list_jra55_fixed_poleward
mean=float(sum(test))/float(len(test))
iwv_max_list_jra55_fixed_poleward_percent=[(x/mean-1.)*100. for x in test]


test=iwv_max_list_merra2_variable
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=iwv_max_list_merra2_variable
mean=float(sum(test))/float(len(test))
iwv_max_list_merra2_variable_percent=[(x/mean-1.)*100. for x in test]

test=iwv_max_list_merra2_fixed
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=iwv_max_list_merra2_fixed
mean=float(sum(test))/float(len(test))
iwv_max_list_merra2_fixed_percent=[(x/mean-1.)*100. for x in test]

test=iwv_max_list_merra2_fixed_poleward
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=iwv_max_list_merra2_fixed_poleward
mean=float(sum(test))/float(len(test))
iwv_max_list_merra2_fixed_poleward_percent=[(x/mean-1.)*100. for x in test]


test_array=np.zeros((9,84))
testa=[np.nan]*40+iwv_max_list_merra2_fixed_percent
testb=[np.nan]*40+iwv_max_list_merra2_fixed_poleward_percent
testc=[np.nan]*40+iwv_max_list_merra2_variable_percent

testa1=[np.nan]*18+iwv_max_list_jra55_fixed_percent
testb1=[np.nan]*18+iwv_max_list_jra55_fixed_poleward_percent
testc1=[np.nan]*18+iwv_max_list_jra55_variable_percent

testa2=iwv_max_list_era5_fixed_percent
testb2=iwv_max_list_era5_fixed_poleward_percent
testc2=iwv_max_list_era5_variable_percent

test_array[0,:]=testa
test_array[1,:]=testb
test_array[2,:]=testc
test_array[3,:]=testa1
test_array[4,:]=testb1
test_array[5,:]=testc1
test_array[6,:]=testa2
test_array[7,:]=testb2
test_array[8,:]=testc2

avg_value=np.nanmean(test_array,axis=0)
min_value=np.nanmin(test_array,axis=0)
max_value=np.nanmax(test_array,axis=0)
    
label='Within-AR maximum IWV, '+str(count)+' significant'
ax.plot(yrs1,avg_value,color='darkred',linewidth=10,label=label)
ax.fill_between(yrs1,min_value,max_value,color='r',alpha=0.6)



ax.tick_params(labelsize=40)
ax.set_xlabel('Year',fontsize=44)
ax.set_ylabel('% anomaly',fontsize=44)
ax.set_title(r'$\bf{AR}$'+' '+r'$\bf{IWV}$'+' '+r'$\bf{land}$',fontsize=61,pad=5)
ax.grid(True,linewidth=2)
plt.legend(loc='upper center',fontsize=36,ncol=1)
ax.set_xlim(1939.3,2023.6)
ax.set_ylim(-8.5,8.5)
ax.set_yticks(np.arange(-6,8,2))
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2.25)

plt.axhline(y=0,linestyle='--',color='k',alpha=0.75,linewidth=3)
plt.show()

# %%
fig.savefig(dir_data+'ar_test2.png')

# %%
yrs=np.arange(1980,2024,1)
yrs1=np.arange(1940,2024,1)
yrs2=np.arange(1958,2024,1)


fig=plt.figure(figsize=(15,15))
ax=plt.subplot(1,1,1)

ax.fill_between([1939,1979.5],-10,10,color='gray',alpha=0.4)

count=0
test=s_list_era5_variable[40:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=s_list_era5_variable
mean=float(sum(test))/float(len(test))
s_list_era5_variable_percent=[(x/mean-1.)*100. for x in test]
 
test=s_list_era5_fixed[40:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=s_list_era5_fixed
mean=float(sum(test))/float(len(test))
s_list_era5_fixed_percent=[(x/mean-1.)*100. for x in test]

test=s_list_era5_fixed_poleward[40:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=s_list_era5_fixed_poleward
mean=float(sum(test))/float(len(test))
s_list_era5_fixed_poleward_percent=[(x/mean-1.)*100. for x in test]
    

test=s_list_jra55_variable[22:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=s_list_jra55_variable
mean=float(sum(test))/float(len(test))
s_list_jra55_variable_percent=[(x/mean-1.)*100. for x in test]
 
test=s_list_jra55_fixed[22:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=s_list_jra55_fixed
mean=float(sum(test))/float(len(test))
s_list_jra55_fixed_percent=[(x/mean-1.)*100. for x in test]

test=s_list_jra55_fixed_poleward[22:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=s_list_jra55_fixed_poleward
mean=float(sum(test))/float(len(test))
s_list_jra55_fixed_poleward_percent=[(x/mean-1.)*100. for x in test]


test=s_list_merra2_variable
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=s_list_merra2_variable
mean=float(sum(test))/float(len(test))
s_list_merra2_variable_percent=[(x/mean-1.)*100. for x in test]

test=s_list_merra2_fixed
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=s_list_merra2_fixed
mean=float(sum(test))/float(len(test))
s_list_merra2_fixed_percent=[(x/mean-1.)*100. for x in test]

test=s_list_merra2_fixed_poleward
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=s_list_merra2_fixed_poleward
mean=float(sum(test))/float(len(test))
s_list_merra2_fixed_poleward_percent=[(x/mean-1.)*100. for x in test]


test_array=np.zeros((9,84))
testa=[np.nan]*40+s_list_merra2_fixed_percent
testb=[np.nan]*40+s_list_merra2_fixed_poleward_percent
testc=[np.nan]*40+s_list_merra2_variable_percent

testa1=[np.nan]*18+s_list_jra55_fixed_percent
testb1=[np.nan]*18+s_list_jra55_fixed_poleward_percent
testc1=[np.nan]*18+s_list_jra55_variable_percent

testa2=s_list_era5_fixed_percent
testb2=s_list_era5_fixed_poleward_percent
testc2=s_list_era5_variable_percent

test_array[0,:]=testa
test_array[1,:]=testb
test_array[2,:]=testc
test_array[3,:]=testa1
test_array[4,:]=testb1
test_array[5,:]=testc1
test_array[6,:]=testa2
test_array[7,:]=testb2
test_array[8,:]=testc2

avg_value=np.nanmean(test_array,axis=0)
min_value=np.nanmin(test_array,axis=0)
max_value=np.nanmax(test_array,axis=0)
    
label='Within-AR mean wind, '+str(count)+' significant'
ax.plot(yrs1,avg_value,color='k',linewidth=10,label=label)
ax.fill_between(yrs1,min_value,max_value,color='gray',alpha=0.6)


#####

count=0
test=s_max_list_era5_variable[40:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=s_max_list_era5_variable
mean=float(sum(test))/float(len(test))
s_max_list_era5_variable_percent=[(x/mean-1.)*100. for x in test]
 
test=s_max_list_era5_fixed[40:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=s_max_list_era5_fixed
mean=float(sum(test))/float(len(test))
s_max_list_era5_fixed_percent=[(x/mean-1.)*100. for x in test]

test=s_max_list_era5_fixed_poleward[40:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=s_max_list_era5_fixed_poleward
mean=float(sum(test))/float(len(test))
s_max_list_era5_fixed_poleward_percent=[(x/mean-1.)*100. for x in test]
    

test=s_max_list_jra55_variable[22:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=s_max_list_jra55_variable
mean=float(sum(test))/float(len(test))
s_max_list_jra55_variable_percent=[(x/mean-1.)*100. for x in test]
 
test=s_max_list_jra55_fixed[22:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=s_max_list_jra55_fixed
mean=float(sum(test))/float(len(test))
s_max_list_jra55_fixed_percent=[(x/mean-1.)*100. for x in test]

test=s_max_list_jra55_fixed_poleward[22:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=s_max_list_jra55_fixed_poleward
mean=float(sum(test))/float(len(test))
s_max_list_jra55_fixed_poleward_percent=[(x/mean-1.)*100. for x in test]


test=s_max_list_merra2_variable
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=s_max_list_merra2_variable
mean=float(sum(test))/float(len(test))
s_max_list_merra2_variable_percent=[(x/mean-1.)*100. for x in test]

test=s_max_list_merra2_fixed
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=s_max_list_merra2_fixed
mean=float(sum(test))/float(len(test))
s_max_list_merra2_fixed_percent=[(x/mean-1.)*100. for x in test]

test=s_max_list_merra2_fixed_poleward
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=s_max_list_merra2_fixed_poleward
mean=float(sum(test))/float(len(test))
s_max_list_merra2_fixed_poleward_percent=[(x/mean-1.)*100. for x in test]


test_array=np.zeros((9,84))
testa=[np.nan]*40+s_max_list_merra2_fixed_percent
testb=[np.nan]*40+s_max_list_merra2_fixed_poleward_percent
testc=[np.nan]*40+s_max_list_merra2_variable_percent

testa1=[np.nan]*18+s_max_list_jra55_fixed_percent
testb1=[np.nan]*18+s_max_list_jra55_fixed_poleward_percent
testc1=[np.nan]*18+s_max_list_jra55_variable_percent

testa2=s_max_list_era5_fixed_percent
testb2=s_max_list_era5_fixed_poleward_percent
testc2=s_max_list_era5_variable_percent

test_array[0,:]=testa
test_array[1,:]=testb
test_array[2,:]=testc
test_array[3,:]=testa1
test_array[4,:]=testb1
test_array[5,:]=testc1
test_array[6,:]=testa2
test_array[7,:]=testb2
test_array[8,:]=testc2

avg_value=np.nanmean(test_array,axis=0)
min_value=np.nanmin(test_array,axis=0)
max_value=np.nanmax(test_array,axis=0)
    
label='Within-AR maximum wind, '+str(count)+' significant'
ax.plot(yrs1,avg_value,color='darkred',linewidth=10,label=label)
ax.fill_between(yrs1,min_value,max_value,color='r',alpha=0.6)



ax.tick_params(labelsize=40)
ax.set_xlabel('Year',fontsize=44)
ax.set_ylabel('% anomaly',fontsize=44)
ax.set_title(r'$\bf{AR}$'+' '+r'$\bf{wind}$'+' '+r'$\bf{land}$',fontsize=61,pad=5)
ax.grid(True,linewidth=2)
plt.legend(loc='upper center',fontsize=35.5,ncol=1)
ax.set_xlim(1939.3,2023.6)
ax.set_ylim(-8.5,8.5)
ax.set_yticks(np.arange(-6,8,2))
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2.25)

plt.axhline(y=0,linestyle='--',color='k',alpha=0.75,linewidth=3)
plt.show()

# %%
fig.savefig(dir_data+'ar_test3.png')

# %%
yrs=np.arange(1980,2024,1)
yrs1=np.arange(1940,2024,1)
yrs2=np.arange(1958,2024,1)


fig=plt.figure(figsize=(15,15))
ax=plt.subplot(1,1,1)

ax.fill_between([1939,1979.5],-24,24,color='gray',alpha=0.4)

count=0
test=mfc_list_era5_variable[40:]
r=st.linregress(yrs,test)
print(r)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=mfc_list_era5_variable
mean=float(sum(test))/float(len(test))
mfc_list_era5_variable_percent=[(x/mean-1.)*100. for x in test]
 
test=mfc_list_era5_fixed[40:]
r=st.linregress(yrs,test)
print(r)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=mfc_list_era5_fixed
mean=float(sum(test))/float(len(test))
mfc_list_era5_fixed_percent=[(x/mean-1.)*100. for x in test]

test=mfc_list_era5_fixed_poleward[40:]
r=st.linregress(yrs,test)
print(r)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=mfc_list_era5_fixed_poleward
mean=float(sum(test))/float(len(test))
mfc_list_era5_fixed_poleward_percent=[(x/mean-1.)*100. for x in test]
    

test=mfc_list_merra2_variable
r=st.linregress(yrs,test)
print(r)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=mfc_list_merra2_variable
mean=float(sum(test))/float(len(test))
mfc_list_merra2_variable_percent=[(x/mean-1.)*100. for x in test]

test=mfc_list_merra2_fixed
r=st.linregress(yrs,test)
print(r)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=mfc_list_merra2_fixed
mean=float(sum(test))/float(len(test))
mfc_list_merra2_fixed_percent=[(x/mean-1.)*100. for x in test]

test=mfc_list_merra2_fixed_poleward
r=st.linregress(yrs,test)
print(r)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=mfc_list_merra2_fixed_poleward
mean=float(sum(test))/float(len(test))
mfc_list_merra2_fixed_poleward_percent=[(x/mean-1.)*100. for x in test]


test_array=np.zeros((6,84))
testa=[np.nan]*40+mfc_list_merra2_fixed_percent
testb=[np.nan]*40+mfc_list_merra2_fixed_poleward_percent
testc=[np.nan]*40+mfc_list_merra2_variable_percent

testa2=mfc_list_era5_fixed_percent
testb2=mfc_list_era5_fixed_poleward_percent
testc2=mfc_list_era5_variable_percent

test_array[0,:]=testa
test_array[1,:]=testb
test_array[2,:]=testc
test_array[3,:]=testa2
test_array[4,:]=testb2
test_array[5,:]=testc2

avg_value=np.nanmean(test_array,axis=0)
min_value=np.nanmin(test_array,axis=0)
max_value=np.nanmax(test_array,axis=0)
    
label='Within-AR mean MFC, '+str(count)+' significant'
ax.plot(yrs1,avg_value,color='k',linewidth=10,label=label)
ax.fill_between(yrs1,min_value,max_value,color='gray',alpha=0.6)


#####

count=0
test=mfc_max_list_era5_variable[40:]
r=st.linregress(yrs,test)
print(r)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=mfc_max_list_era5_variable
mean=float(sum(test))/float(len(test))
mfc_max_list_era5_variable_percent=[(x/mean-1.)*100. for x in test]
 
test=mfc_max_list_era5_fixed[40:]
r=st.linregress(yrs,test)
print(r)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=mfc_max_list_era5_fixed
mean=float(sum(test))/float(len(test))
mfc_max_list_era5_fixed_percent=[(x/mean-1.)*100. for x in test]

test=mfc_max_list_era5_fixed_poleward[40:]
r=st.linregress(yrs,test)
print(r)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=mfc_max_list_era5_fixed_poleward
mean=float(sum(test))/float(len(test))
mfc_max_list_era5_fixed_poleward_percent=[(x/mean-1.)*100. for x in test]
    

test=mfc_max_list_merra2_variable
r=st.linregress(yrs,test)
print(r)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=mfc_max_list_merra2_variable
mean=float(sum(test))/float(len(test))
mfc_max_list_merra2_variable_percent=[(x/mean-1.)*100. for x in test]

test=mfc_max_list_merra2_fixed
r=st.linregress(yrs,test)
print(r)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=mfc_max_list_merra2_fixed
mean=float(sum(test))/float(len(test))
mfc_max_list_merra2_fixed_percent=[(x/mean-1.)*100. for x in test]

test=mfc_max_list_merra2_fixed_poleward
r=st.linregress(yrs,test)
print(r)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=mfc_max_list_merra2_fixed_poleward
mean=float(sum(test))/float(len(test))
mfc_max_list_merra2_fixed_poleward_percent=[(x/mean-1.)*100. for x in test]


test_array=np.zeros((6,84))
testa=[np.nan]*40+mfc_max_list_merra2_fixed_percent
testb=[np.nan]*40+mfc_max_list_merra2_fixed_poleward_percent
testc=[np.nan]*40+mfc_max_list_merra2_variable_percent

testa2=mfc_max_list_era5_fixed_percent
testb2=mfc_max_list_era5_fixed_poleward_percent
testc2=mfc_max_list_era5_variable_percent

test_array[0,:]=testa
test_array[1,:]=testb
test_array[2,:]=testc
test_array[3,:]=testa2
test_array[4,:]=testb2
test_array[5,:]=testc2

avg_value=np.nanmean(test_array,axis=0)
min_value=np.nanmin(test_array,axis=0)
max_value=np.nanmax(test_array,axis=0)
    
label='Within-AR maximum MFC, '+str(count)+' significant'
ax.plot(yrs1,avg_value,color='darkred',linewidth=10,label=label)
ax.fill_between(yrs1,min_value,max_value,color='r',alpha=0.6)



ax.tick_params(labelsize=40)
ax.set_xlabel('Year',fontsize=44)
ax.set_ylabel('% anomaly',fontsize=44)
ax.set_title(r'$\bf{AR}$'+' '+r'$\bf{MFC}$'+' '+r'$\bf{land}$',fontsize=61,pad=5)
ax.grid(True,linewidth=2)
plt.legend(loc='upper center',fontsize=36,ncol=1)
ax.set_xlim(1939.3,2023.6)
ax.set_ylim(-24,24)
#ax.set_yticks(np.arange(-25,30,5))
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2.5)

plt.axhline(y=0,linestyle='--',color='k',alpha=0.75,linewidth=3)
plt.show()

# %%
fig.savefig(dir_data+'ar_test4.png')

# %%
ds=xr.open_dataset(dir_data+'ar_area_land.nc')
areas_array_era5_fixed=ds['areas_array_era5_fixed'].values/1e6
areas_array_jra55_fixed=ds['areas_array_jra55_fixed'].values/1e6
areas_array_merra2_fixed=ds['areas_array_merra2_fixed'].values/1e6

areas_array_era5_fixed_poleward=ds['areas_array_era5_fixed_poleward'].values/1e6
areas_array_jra55_fixed_poleward=ds['areas_array_jra55_fixed_poleward'].values/1e6
areas_array_merra2_fixed_poleward=ds['areas_array_merra2_fixed_poleward'].values/1e6

areas_array_era5_variable=ds['areas_array_era5_variable'].values/1e6
areas_array_jra55_variable=ds['areas_array_jra55_variable'].values/1e6
areas_array_merra2_variable=ds['areas_array_merra2_variable'].values/1e6

areas_list_era5_fixed=[x/1e6 for x in ds['areas_list_era5_fixed'].values.tolist()]
areas_list_jra55_fixed=[x/1e6 for x in ds['areas_list_jra55_fixed'].values.tolist()]
areas_list_merra2_fixed=[x/1e6 for x in ds['areas_list_merra2_fixed'].values.tolist()]

areas_list_era5_fixed_poleward=[x/1e6 for x in ds['areas_list_era5_fixed_poleward'].values.tolist()]
areas_list_jra55_fixed_poleward=[x/1e6 for x in ds['areas_list_jra55_fixed_poleward'].values.tolist()]
areas_list_merra2_fixed_poleward=[x/1e6 for x in ds['areas_list_merra2_fixed_poleward'].values.tolist()]

areas_list_era5_variable=[x/1e6 for x in ds['areas_list_era5_variable'].values.tolist()]
areas_list_jra55_variable=[x/1e6 for x in ds['areas_list_jra55_variable'].values.tolist()]
areas_list_merra2_variable=[x/1e6 for x in ds['areas_list_merra2_variable'].values.tolist()]


ds=xr.open_dataset(dir_data+'ar_area_ocean.nc')
areas_array_era5_fixed1=ds['areas_array_era5_fixed'].values/1e6
areas_array_jra55_fixed1=ds['areas_array_jra55_fixed'].values/1e6
areas_array_merra2_fixed1=ds['areas_array_merra2_fixed'].values/1e6

areas_array_era5_fixed_poleward1=ds['areas_array_era5_fixed_poleward'].values/1e6
areas_array_jra55_fixed_poleward1=ds['areas_array_jra55_fixed_poleward'].values/1e6
areas_array_merra2_fixed_poleward1=ds['areas_array_merra2_fixed_poleward'].values/1e6

areas_array_era5_variable1=ds['areas_array_era5_variable'].values/1e6
areas_array_jra55_variable1=ds['areas_array_jra55_variable'].values/1e6
areas_array_merra2_variable1=ds['areas_array_merra2_variable'].values/1e6

areas_list_era5_fixed1=[x/1e6 for x in ds['areas_list_era5_fixed'].values.tolist()]
areas_list_jra55_fixed1=[x/1e6 for x in ds['areas_list_jra55_fixed'].values.tolist()]
areas_list_merra2_fixed1=[x/1e6 for x in ds['areas_list_merra2_fixed'].values.tolist()]

areas_list_era5_fixed_poleward1=[x/1e6 for x in ds['areas_list_era5_fixed_poleward'].values.tolist()]
areas_list_jra55_fixed_poleward1=[x/1e6 for x in ds['areas_list_jra55_fixed_poleward'].values.tolist()]
areas_list_merra2_fixed_poleward1=[x/1e6 for x in ds['areas_list_merra2_fixed_poleward'].values.tolist()]

areas_list_era5_variable1=[x/1e6 for x in ds['areas_list_era5_variable'].values.tolist()]
areas_list_jra55_variable1=[x/1e6 for x in ds['areas_list_jra55_variable'].values.tolist()]
areas_list_merra2_variable1=[x/1e6 for x in ds['areas_list_merra2_variable'].values.tolist()]

# %%
yrs=np.arange(1980,2024,1)
yrs1=np.arange(1940,2024,1)
yrs2=np.arange(1958,2024,1)


fig=plt.figure(figsize=(20,10))
ax=plt.subplot(1,1,1)

ax.fill_between([1939,1979.5],-39,39,color='gray',alpha=0.4)

count=0
test=areas_list_era5_variable[40:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=areas_list_era5_variable
mean=float(sum(test))/float(len(test))
areas_list_era5_variable_percent=[(x/mean-1.)*100. for x in test]
 
test=areas_list_era5_fixed[40:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=areas_list_era5_fixed
mean=float(sum(test))/float(len(test))
areas_list_era5_fixed_percent=[(x/mean-1.)*100. for x in test]

test=areas_list_era5_fixed_poleward[40:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=areas_list_era5_fixed_poleward
mean=float(sum(test))/float(len(test))
areas_list_era5_fixed_poleward_percent=[(x/mean-1.)*100. for x in test]
    

test=areas_list_jra55_variable[22:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=areas_list_jra55_variable
mean=float(sum(test))/float(len(test))
areas_list_jra55_variable_percent=[(x/mean-1.)*100. for x in test]
 
test=areas_list_jra55_fixed[22:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=areas_list_jra55_fixed
mean=float(sum(test))/float(len(test))
areas_list_jra55_fixed_percent=[(x/mean-1.)*100. for x in test]

test=areas_list_jra55_fixed_poleward[22:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=areas_list_jra55_fixed_poleward
mean=float(sum(test))/float(len(test))
areas_list_jra55_fixed_poleward_percent=[(x/mean-1.)*100. for x in test]


test=areas_list_merra2_variable
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=areas_list_merra2_variable
mean=float(sum(test))/float(len(test))
areas_list_merra2_variable_percent=[(x/mean-1.)*100. for x in test]

test=areas_list_merra2_fixed
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=areas_list_merra2_fixed
mean=float(sum(test))/float(len(test))
areas_list_merra2_fixed_percent=[(x/mean-1.)*100. for x in test]

test=areas_list_merra2_fixed_poleward
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=areas_list_merra2_fixed_poleward
mean=float(sum(test))/float(len(test))
areas_list_merra2_fixed_poleward_percent=[(x/mean-1.)*100. for x in test]


test_array=np.zeros((9,84))
testa=[np.nan]*40+areas_list_merra2_fixed_percent
testb=[np.nan]*40+areas_list_merra2_fixed_poleward_percent
testc=[np.nan]*40+areas_list_merra2_variable_percent

testa1=[np.nan]*18+areas_list_jra55_fixed_percent
testb1=[np.nan]*18+areas_list_jra55_fixed_poleward_percent
testc1=[np.nan]*18+areas_list_jra55_variable_percent

testa2=areas_list_era5_fixed_percent
testb2=areas_list_era5_fixed_poleward_percent
testc2=areas_list_era5_variable_percent

test_array[0,:]=testa
test_array[1,:]=testb
test_array[2,:]=testc
test_array[3,:]=testa1
test_array[4,:]=testb1
test_array[5,:]=testc1
test_array[6,:]=testa2
test_array[7,:]=testb2
test_array[8,:]=testc2

avg_value=np.nanmean(test_array,axis=0)
min_value=np.nanmin(test_array,axis=0)
max_value=np.nanmax(test_array,axis=0)
    
label='Total AR land area, '+str(count)+' significant'
ax.plot(yrs1,avg_value,color='k',linewidth=9,label=label)
ax.fill_between(yrs1,min_value,max_value,color='gray',alpha=0.5)


############


count=0
test=areas_list_era5_variable1[40:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=areas_list_era5_variable1
mean=float(sum(test))/float(len(test))
areas_list_era5_variable_percent1=[(x/mean-1.)*100. for x in test]
 
test=areas_list_era5_fixed1[40:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=areas_list_era5_fixed1
mean=float(sum(test))/float(len(test))
areas_list_era5_fixed_percent1=[(x/mean-1.)*100. for x in test]

test=areas_list_era5_fixed_poleward1[40:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=areas_list_era5_fixed_poleward1
mean=float(sum(test))/float(len(test))
areas_list_era5_fixed_poleward_percent1=[(x/mean-1.)*100. for x in test]
    

test=areas_list_jra55_variable1[22:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=areas_list_jra55_variable1
mean=float(sum(test))/float(len(test))
areas_list_jra55_variable_percent1=[(x/mean-1.)*100. for x in test]
 
test=areas_list_jra55_fixed1[22:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=areas_list_jra55_fixed1
mean=float(sum(test))/float(len(test))
areas_list_jra55_fixed_percent1=[(x/mean-1.)*100. for x in test]

test=areas_list_jra55_fixed_poleward1[22:]
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=areas_list_jra55_fixed_poleward1
mean=float(sum(test))/float(len(test))
areas_list_jra55_fixed_poleward_percent1=[(x/mean-1.)*100. for x in test]


test=areas_list_merra2_variable1
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=areas_list_merra2_variable1
mean=float(sum(test))/float(len(test))
areas_list_merra2_variable_percent1=[(x/mean-1.)*100. for x in test]

test=areas_list_merra2_fixed1
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=areas_list_merra2_fixed1
mean=float(sum(test))/float(len(test))
areas_list_merra2_fixed_percent1=[(x/mean-1.)*100. for x in test]

test=areas_list_merra2_fixed_poleward1
r=st.linregress(yrs,test)
sigs_list.append(r[3])
if r[3]<=0.03651:
    count=count+1
test=areas_list_merra2_fixed_poleward1
mean=float(sum(test))/float(len(test))
areas_list_merra2_fixed_poleward_percent1=[(x/mean-1.)*100. for x in test]


test_array=np.zeros((9,84))
testa=[np.nan]*40+areas_list_merra2_fixed_percent1
testb=[np.nan]*40+areas_list_merra2_fixed_poleward_percent1
testc=[np.nan]*40+areas_list_merra2_variable_percent1

testa1=[np.nan]*18+areas_list_jra55_fixed_percent1
testb1=[np.nan]*18+areas_list_jra55_fixed_poleward_percent1
testc1=[np.nan]*18+areas_list_jra55_variable_percent1

testa2=areas_list_era5_fixed_percent1
testb2=areas_list_era5_fixed_poleward_percent1
testc2=areas_list_era5_variable_percent1

test_array[0,:]=testa
test_array[1,:]=testb
test_array[2,:]=testc
test_array[3,:]=testa1
test_array[4,:]=testb1
test_array[5,:]=testc1
test_array[6,:]=testa2
test_array[7,:]=testb2
test_array[8,:]=testc2

avg_value=np.nanmean(test_array,axis=0)
min_value=np.nanmin(test_array,axis=0)
max_value=np.nanmax(test_array,axis=0)
    
label='Total AR ocean area, '+str(count)+' significant'
ax.plot(yrs1,avg_value,color='b',linewidth=9,label=label)
ax.fill_between(yrs1,min_value,max_value,color='deepskyblue',alpha=0.5)




ax.tick_params(labelsize=30)
ax.set_xlabel('Year',fontsize=32)
ax.set_ylabel('% anomaly',fontsize=32)
ax.set_title(r'$\bf{Total}$'+' '+r'$\bf{AR}$'+' '+r'$\bf{area}$',fontsize=48,pad=5)
ax.grid(True,linewidth=2)
plt.legend(loc='upper left',fontsize=28,ncol=1)
ax.set_xlim(1939.3,2023.6)
ax.set_ylim(-35,35)
#ax.set_yticks(np.arange(-7.5,10,2.5))
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2.25)

plt.axhline(y=0,linestyle='--',color='k',alpha=0.75,linewidth=3)
#Within-AR IVT mean
plt.show()

# %%
fig.savefig(dir_data+'ar_test0.png')

# %%
print(sigs_list)

# %%
print(len(sigs_list))
