# %%
import numpy as np
import xarray as xr
import scipy.stats as st
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import requests
import os,errno
import sys
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER,LATITUDE_FORMATTER
import matplotlib.ticker as mticker
import cartopy.feature as cfeature
import datetime as dt
import pandas as pd
import time
import urllib.request
import metpy.calc as mpcalc
import salem
import scipy.optimize as opt
import warnings
import geopy.distance
import matplotlib as mpl

from scipy.ndimage.measurements import label
from scipy.ndimage import binary_dilation

warnings.filterwarnings('ignore')

dir_data='/Users/ahenny/'
dir2='/Volumes/Extreme Pro/'
dir3='/Volumes/My Passport/'

# %%
ds=xr.open_dataset(dir2+'jra55.ar.duration_chars.model.poleward.nc')
ivt_concat_jra55_fixed_poleward=ds['max_ivt']
iwv_concat_jra55_fixed_poleward=ds['max_iwv']
s_concat_jra55_fixed_poleward=ds['max_s']
duration_concat_jra55_fixed_poleward=ds['duration']
freq_4_concat_jra55_fixed_poleward=ds['freq_4']

ds=xr.open_dataset(dir2+'jra55.ar.duration_chars.model.fixed.nc')
ivt_concat_jra55_fixed=ds['max_ivt']
iwv_concat_jra55_fixed=ds['max_iwv']
s_concat_jra55_fixed=ds['max_s']
duration_concat_jra55_fixed=ds['duration']
freq_4_concat_jra55_fixed=ds['freq_4']

ds=xr.open_dataset(dir2+'jra55.ar.duration_chars.model.variable.nc')
ivt_concat_jra55_variable=ds['max_ivt']
iwv_concat_jra55_variable=ds['max_iwv']
s_concat_jra55_variable=ds['max_s']
duration_concat_jra55_variable=ds['duration']
freq_4_concat_jra55_variable=ds['freq_4']


ds=xr.open_dataset(dir2+'era5.ar.duration_chars.model.poleward.nc')
ivt_concat_era5_fixed_poleward=ds['max_ivt']
iwv_concat_era5_fixed_poleward=ds['max_iwv']
s_concat_era5_fixed_poleward=ds['max_s']
mfc_concat_era5_fixed_poleward=ds['max_mfc']
duration_concat_era5_fixed_poleward=ds['duration']
freq_4_concat_era5_fixed_poleward=ds['freq_4']

ds=xr.open_dataset(dir2+'era5.ar.duration_chars.model.fixed.nc')
ivt_concat_era5_fixed=ds['max_ivt']
iwv_concat_era5_fixed=ds['max_iwv']
s_concat_era5_fixed=ds['max_s']
mfc_concat_era5_fixed=ds['max_mfc']
duration_concat_era5_fixed=ds['duration']
freq_4_concat_era5_fixed=ds['freq_4']

ds=xr.open_dataset(dir2+'era5.ar.duration_chars.model.variable.nc')
ivt_concat_era5_variable=ds['max_ivt']
iwv_concat_era5_variable=ds['max_iwv']
s_concat_era5_variable=ds['max_s']
mfc_concat_era5_variable=ds['max_mfc']
duration_concat_era5_variable=ds['duration']
freq_4_concat_era5_variable=ds['freq_4']


ds=xr.open_dataset(dir2+'merra2.ar.duration_chars.model.poleward.nc')
ivt_concat_merra2_fixed_poleward=ds['max_ivt']
iwv_concat_merra2_fixed_poleward=ds['max_iwv']
s_concat_merra2_fixed_poleward=ds['max_s']
mfc_concat_merra2_fixed_poleward=ds['max_mfc']
duration_concat_merra2_fixed_poleward=ds['duration']
freq_4_concat_merra2_fixed_poleward=ds['freq_4']

ds=xr.open_dataset(dir2+'merra2.ar.duration_chars.model.fixed.nc')
ivt_concat_merra2_fixed=ds['max_ivt']
iwv_concat_merra2_fixed=ds['max_iwv']
s_concat_merra2_fixed=ds['max_s']
mfc_concat_merra2_fixed=ds['max_mfc']
duration_concat_merra2_fixed=ds['duration']
freq_4_concat_merra2_fixed=ds['freq_4']

ds=xr.open_dataset(dir2+'merra2.ar.duration_chars.model.variable.nc')
ivt_concat_merra2_variable=ds['max_ivt']
iwv_concat_merra2_variable=ds['max_iwv']
s_concat_merra2_variable=ds['max_s']
mfc_concat_merra2_variable=ds['max_mfc']
duration_concat_merra2_variable=ds['duration']
freq_4_concat_merra2_variable=ds['freq_4']

# %%
fieldc=ivt_concat_era5_fixed.mean(dim='time',skipna=True)
fielda=ivt_concat_merra2_fixed.mean(dim='time',skipna=True)
fieldb=ivt_concat_jra55_fixed.mean(dim='time',skipna=True)
fieldb=fieldb.interp_like(fielda)
field=(fielda+fieldb+fieldc)/3.

field1=ivt_concat_era5_fixed/ivt_concat_era5_fixed
field1=field1.sum(dim='time').values

field1a=ivt_concat_merra2_fixed/ivt_concat_merra2_fixed
field1a=field1a.sum(dim='time')

field1b=ivt_concat_jra55_fixed/ivt_concat_jra55_fixed
field1b=field1b.interp_like(ivt_concat_merra2_fixed)
field1b=field1b.sum(dim='time')

field_freq=(field1+field1a+field1b)/3.

field=field.where(field_freq>=0.8*43)

fig=plt.figure(figsize=(24,11))#24,12
ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
#cax=ax.pcolormesh(field.lon,field.lat,field,vmin=0,vmax=600,cmap=plt.cm.viridis,transform=ccrs.PlateCarree(),alpha=1.0)   
#cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(100,700,100))
cax=ax.contourf(field.lon,field.lat,field,levels=np.arange(0,840,60),extend='max',cmap=plt.cm.viridis,alpha=1.0)
cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(60,840,120))


g1=ax.gridlines(crs=ccrs.PlateCarree(),draw_labels=True,linewidth=1.5,color='gray',alpha=0.0,linestyle='--')
cbar.ax.tick_params(labelsize=47) 
cbar.set_label('kg m$^{-1}$ s$^{-1}$',fontsize=55,labelpad=5)
ax.coastlines(resolution='10m')
countries = cfeature.NaturalEarthFeature(category='cultural',name='admin_0_boundary_lines_land',scale='50m',facecolor='none')
ax.add_feature(countries)
g1.xlabel_style={'size':47,'color':'k'}
g1.ylabel_style={'size':47,'color':'k'}
g1.xformatter=LONGITUDE_FORMATTER
g1.yformatter=LATITUDE_FORMATTER
g1.top_labels=False
g1.right_labels=False

g1.xlocator = mticker.FixedLocator([-120,-60,0,60,120])
            
ax.set_title(r'$\bf{IVT}$'+' '+r'$\bf{fixed}$',fontsize=64,pad=5)

plt.show()

# %%
fig.savefig(dir_data+'ar_vars_maxes_geomeans_1.png')

# %%
fieldc=ivt_concat_era5_fixed_poleward.mean(dim='time',skipna=True)
fielda=ivt_concat_merra2_fixed_poleward.mean(dim='time',skipna=True)
fieldb=ivt_concat_jra55_fixed_poleward.mean(dim='time',skipna=True)
fieldb=fieldb.interp_like(fielda)
field=(fielda+fieldb+fieldc)/3.

field1=ivt_concat_era5_fixed_poleward/ivt_concat_era5_fixed_poleward
field1=field1.sum(dim='time').values

field1a=ivt_concat_merra2_fixed_poleward/ivt_concat_merra2_fixed_poleward
field1a=field1a.sum(dim='time')

field1b=ivt_concat_jra55_fixed_poleward/ivt_concat_jra55_fixed_poleward
field1b=field1b.interp_like(ivt_concat_merra2_fixed_poleward)
field1b=field1b.sum(dim='time')

field_freq=(field1+field1a+field1b)/3.

field=field.where(field_freq>=0.8*43)

fig=plt.figure(figsize=(24,11))#24,12
ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
#cax=ax.pcolormesh(field.lon,field.lat,field,vmin=0,vmax=600,cmap=plt.cm.viridis,transform=ccrs.PlateCarree(),alpha=1.0)   
#cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(100,700,100))
cax=ax.contourf(field.lon,field.lat,field,levels=np.arange(0,840,60),extend='max',cmap=plt.cm.viridis,alpha=1.0)
cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(60,840,120))


g1=ax.gridlines(crs=ccrs.PlateCarree(),draw_labels=True,linewidth=1.5,color='gray',alpha=0.0,linestyle='--')
cbar.ax.tick_params(labelsize=47) 
cbar.set_label('kg m$^{-1}$ s$^{-1}$',fontsize=55,labelpad=5)
ax.coastlines(resolution='10m')
countries = cfeature.NaturalEarthFeature(category='cultural',name='admin_0_boundary_lines_land',scale='50m',facecolor='none')
ax.add_feature(countries)
g1.xlabel_style={'size':47,'color':'k'}
g1.ylabel_style={'size':47,'color':'k'}
g1.xformatter=LONGITUDE_FORMATTER
g1.yformatter=LATITUDE_FORMATTER
g1.top_labels=False
g1.right_labels=False

g1.xlocator = mticker.FixedLocator([-120,-60,0,60,120])
            
ax.set_title(r'$\bf{IVT}$'+' '+r'$\bf{fixed}$'+' '+r'$\bf{poleward}$',fontsize=64,pad=5)

plt.show()

# %%
fig.savefig(dir_data+'ar_vars_maxes_geomeans_2.png')

# %%
fieldc=ivt_concat_era5_variable.mean(dim='time',skipna=True)
fielda=ivt_concat_merra2_variable.mean(dim='time',skipna=True)
fieldb=ivt_concat_jra55_variable.mean(dim='time',skipna=True)
fieldb=fieldb.interp_like(fielda)
field=(fielda+fieldb+fieldc)/3.

field1=ivt_concat_era5_variable/ivt_concat_era5_variable
field1=field1.sum(dim='time').values

field1a=ivt_concat_merra2_variable/ivt_concat_merra2_variable
field1a=field1a.sum(dim='time')

field1b=ivt_concat_jra55_variable/ivt_concat_jra55_variable
field1b=field1b.interp_like(ivt_concat_merra2_variable)
field1b=field1b.sum(dim='time')

field_freq=(field1+field1a+field1b)/3.

field=field.where(field_freq>=0.8*43)

fig=plt.figure(figsize=(24,11))#24,12
ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
#cax=ax.pcolormesh(field.lon,field.lat,field,vmin=0,vmax=600,cmap=plt.cm.viridis,transform=ccrs.PlateCarree(),alpha=1.0)   
#cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(100,700,100))
cax=ax.contourf(field.lon,field.lat,field,levels=np.arange(0,840,60),extend='max',cmap=plt.cm.viridis,alpha=1.0)
cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(60,840,120))


g1=ax.gridlines(crs=ccrs.PlateCarree(),draw_labels=True,linewidth=1.5,color='gray',alpha=0.0,linestyle='--')
cbar.ax.tick_params(labelsize=47) 
cbar.set_label('kg m$^{-1}$ s$^{-1}$',fontsize=55,labelpad=5)
ax.coastlines(resolution='10m')
countries = cfeature.NaturalEarthFeature(category='cultural',name='admin_0_boundary_lines_land',scale='50m',facecolor='none')
ax.add_feature(countries)
g1.xlabel_style={'size':47,'color':'k'}
g1.ylabel_style={'size':47,'color':'k'}
g1.xformatter=LONGITUDE_FORMATTER
g1.yformatter=LATITUDE_FORMATTER
g1.top_labels=False
g1.right_labels=False

g1.xlocator = mticker.FixedLocator([-120,-60,0,60,120])
            
ax.set_title(r'$\bf{IVT}$'+' '+r'$\bf{variable}$',fontsize=64,pad=5)

plt.show()

# %%
fig.savefig(dir_data+'ar_vars_maxes_geomeans_3.png')

# %%
fieldc=iwv_concat_era5_fixed.mean(dim='time',skipna=True)
fielda=iwv_concat_merra2_fixed.mean(dim='time',skipna=True)
fieldb=iwv_concat_jra55_fixed.mean(dim='time',skipna=True)
fieldb=fieldb.interp_like(fielda)
field=(fielda+fieldb+fieldc)/3.

field1=ivt_concat_era5_fixed/ivt_concat_era5_fixed
field1=field1.sum(dim='time').values

field1a=ivt_concat_merra2_fixed/ivt_concat_merra2_fixed
field1a=field1a.sum(dim='time')

field1b=ivt_concat_jra55_fixed/ivt_concat_jra55_fixed
field1b=field1b.interp_like(ivt_concat_merra2_fixed)
field1b=field1b.sum(dim='time')

field_freq=(field1+field1a+field1b)/3.

field=field.where(field_freq>=0.8*43)

fig=plt.figure(figsize=(24,11))#24,12
ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
#cax=ax.pcolormesh(field.lon,field.lat,field,vmin=0,vmax=70,cmap=plt.cm.viridis,transform=ccrs.PlateCarree(),alpha=1.0)   
cax=ax.contourf(field.lon,field.lat,field,levels=np.arange(0,64,8),extend='max',cmap=plt.cm.viridis,alpha=1.0)
cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(8,64,8))

g1=ax.gridlines(crs=ccrs.PlateCarree(),draw_labels=True,linewidth=1.5,color='gray',alpha=0.0,linestyle='--')
cbar.ax.tick_params(labelsize=47) 
cbar.set_label('kg m$^{-2}$',fontsize=55,labelpad=5)
ax.coastlines(resolution='10m')
countries = cfeature.NaturalEarthFeature(category='cultural',name='admin_0_boundary_lines_land',scale='50m',facecolor='none')
ax.add_feature(countries)
g1.xlabel_style={'size':47,'color':'k'}
g1.ylabel_style={'size':47,'color':'k'}
g1.xformatter=LONGITUDE_FORMATTER
g1.yformatter=LATITUDE_FORMATTER
g1.top_labels=False
g1.right_labels=False

g1.xlocator = mticker.FixedLocator([-120,-60,0,60,120])
            
ax.set_title(r'$\bf{IWV}$'+' '+r'$\bf{fixed}$',fontsize=64,pad=5)

plt.show()

# %%
fig.savefig(dir_data+'ar_vars_maxes_geomeans_4.png')

# %%
fieldc=iwv_concat_era5_fixed_poleward.mean(dim='time',skipna=True)
fielda=iwv_concat_merra2_fixed_poleward.mean(dim='time',skipna=True)
fieldb=iwv_concat_jra55_fixed_poleward.mean(dim='time',skipna=True)
fieldb=fieldb.interp_like(fielda)
field=(fielda+fieldb+fieldc)/3.

field1=ivt_concat_era5_fixed_poleward/ivt_concat_era5_fixed_poleward
field1=field1.sum(dim='time').values

field1a=ivt_concat_merra2_fixed_poleward/ivt_concat_merra2_fixed_poleward
field1a=field1a.sum(dim='time')

field1b=ivt_concat_jra55_fixed_poleward/ivt_concat_jra55_fixed_poleward
field1b=field1b.interp_like(ivt_concat_merra2_fixed_poleward)
field1b=field1b.sum(dim='time')

field_freq=(field1+field1a+field1b)/3.

field=field.where(field_freq>=0.8*43)

fig=plt.figure(figsize=(24,11))#24,12
ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
#cax=ax.pcolormesh(field.lon,field.lat,field,vmin=0,vmax=50,cmap=plt.cm.viridis,transform=ccrs.PlateCarree(),alpha=1.0)   
#cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(10,60,10))
cax=ax.contourf(field.lon,field.lat,field,levels=np.arange(0,64,8),extend='max',cmap=plt.cm.viridis,alpha=1.0)
cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(8,64,8))

g1=ax.gridlines(crs=ccrs.PlateCarree(),draw_labels=True,linewidth=1.5,color='gray',alpha=0.0,linestyle='--')
cbar.ax.tick_params(labelsize=47) 
cbar.set_label('kg m$^{-2}$',fontsize=55,labelpad=5)
ax.coastlines(resolution='10m')
countries = cfeature.NaturalEarthFeature(category='cultural',name='admin_0_boundary_lines_land',scale='50m',facecolor='none')
ax.add_feature(countries)
g1.xlabel_style={'size':47,'color':'k'}
g1.ylabel_style={'size':47,'color':'k'}
g1.xformatter=LONGITUDE_FORMATTER
g1.yformatter=LATITUDE_FORMATTER
g1.top_labels=False
g1.right_labels=False

g1.xlocator = mticker.FixedLocator([-120,-60,0,60,120])
            
ax.set_title(r'$\bf{IWV}$'+' '+r'$\bf{fixed}$'+' '+r'$\bf{poleward}$',fontsize=64,pad=5)

plt.show()

# %%
fig.savefig(dir_data+'ar_vars_maxes_geomeans_5.png')

# %%
fieldc=iwv_concat_era5_variable.mean(dim='time',skipna=True)
fielda=iwv_concat_merra2_variable.mean(dim='time',skipna=True)
fieldb=iwv_concat_jra55_variable.mean(dim='time',skipna=True)
fieldb=fieldb.interp_like(fielda)
field=(fielda+fieldb+fieldc)/3.

field1=ivt_concat_era5_variable/ivt_concat_era5_variable
field1=field1.sum(dim='time').values

field1a=ivt_concat_merra2_variable/ivt_concat_merra2_variable
field1a=field1a.sum(dim='time')

field1b=ivt_concat_jra55_variable/ivt_concat_jra55_variable
field1b=field1b.interp_like(ivt_concat_merra2_variable)
field1b=field1b.sum(dim='time')

field_freq=(field1+field1a+field1b)/3.

field=field.where(field_freq>=0.8*43)

fig=plt.figure(figsize=(24,11))#24,12
ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
#cax=ax.pcolormesh(field.lon,field.lat,field,vmin=0,vmax=50,cmap=plt.cm.viridis,transform=ccrs.PlateCarree(),alpha=1.0)   
#cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(10,60,10))
cax=ax.contourf(field.lon,field.lat,field,levels=np.arange(0,64,8),extend='max',cmap=plt.cm.viridis,alpha=1.0)
cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(8,64,8))


g1=ax.gridlines(crs=ccrs.PlateCarree(),draw_labels=True,linewidth=1.5,color='gray',alpha=0.0,linestyle='--')
cbar.ax.tick_params(labelsize=47) 
cbar.set_label('kg m$^{-2}$',fontsize=55,labelpad=5)
ax.coastlines(resolution='10m')
countries = cfeature.NaturalEarthFeature(category='cultural',name='admin_0_boundary_lines_land',scale='50m',facecolor='none')
ax.add_feature(countries)
g1.xlabel_style={'size':47,'color':'k'}
g1.ylabel_style={'size':47,'color':'k'}
g1.xformatter=LONGITUDE_FORMATTER
g1.yformatter=LATITUDE_FORMATTER
g1.top_labels=False
g1.right_labels=False

g1.xlocator = mticker.FixedLocator([-120,-60,0,60,120])
            
ax.set_title(r'$\bf{IWV}$'+' '+r'$\bf{variable}$',fontsize=64,pad=5)

plt.show()

# %%
fig.savefig(dir_data+'ar_vars_maxes_geomeans_6.png')

# %%
fieldc=s_concat_era5_fixed.mean(dim='time',skipna=True)
fielda=s_concat_merra2_fixed.mean(dim='time',skipna=True)
fieldb=s_concat_jra55_fixed.mean(dim='time',skipna=True)

dk=xr.Dataset()
dk['test']=(('lat','lon'),fieldb.values)
dk.coords['lat']=fieldb.lat1.values
dk.coords['lon']=fieldb.lon1.values
fieldb=dk['test']

fieldb=fieldb.interp_like(fielda)
field=(fielda+fieldb+fieldc)/3.

field1=ivt_concat_era5_fixed/ivt_concat_era5_fixed
field1=field1.sum(dim='time')

field1a=ivt_concat_merra2_fixed/ivt_concat_merra2_fixed
field1a=field1a.sum(dim='time')

field1b=ivt_concat_jra55_fixed/ivt_concat_jra55_fixed

dk=xr.Dataset()
dk['test']=(('time','lat','lon'),field1b.values)
dk.coords['time']=field1b.time.values
dk.coords['lat']=field1b.lat.values
dk.coords['lon']=field1b.lon.values
field1b=dk['test']


field1b=field1b.interp_like(duration_concat_merra2_fixed)
field1b=field1b.sum(dim='time')

field_freq=(field1+field1a+field1b)/3.

field=field.where(field_freq>=0.8*43)

fig=plt.figure(figsize=(24,11))#24,12
ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
#cax=ax.pcolormesh(field.lon,field.lat,field,vmin=0,vmax=25,cmap=plt.cm.viridis,transform=ccrs.PlateCarree(),alpha=1.0)   
#cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(5,30,5))
cax=ax.contourf(field.lon,field.lat,field,levels=np.arange(0,33,3),extend='max',cmap=plt.cm.viridis,alpha=1.0)
cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(3,33,6))

g1=ax.gridlines(crs=ccrs.PlateCarree(),draw_labels=True,linewidth=1.5,color='gray',alpha=0.0,linestyle='--')
cbar.ax.tick_params(labelsize=47) 
cbar.set_label('m s$^{-1}$',fontsize=55,labelpad=15)
ax.coastlines(resolution='10m')
countries = cfeature.NaturalEarthFeature(category='cultural',name='admin_0_boundary_lines_land',scale='50m',facecolor='none')
ax.add_feature(countries)
g1.xlabel_style={'size':47,'color':'k'}
g1.ylabel_style={'size':47,'color':'k'}
g1.xformatter=LONGITUDE_FORMATTER
g1.yformatter=LATITUDE_FORMATTER
g1.top_labels=False
g1.right_labels=False

g1.xlocator = mticker.FixedLocator([-120,-60,0,60,120])
            
ax.set_title(r'$\bf{850}$'+' '+r'$\bf{hPa}$'+' '+r'$\bf{wind}$'+' '+r'$\bf{speed}$'+' '+r'$\bf{fixed}$',fontsize=64,pad=5)

plt.show()

# %%
fig.savefig(dir_data+'ar_vars_maxes_geomeans_7.png')

# %%
fieldc=s_concat_era5_fixed_poleward.mean(dim='time',skipna=True)
fielda=s_concat_merra2_fixed_poleward.mean(dim='time',skipna=True)
fieldb=s_concat_jra55_fixed_poleward.mean(dim='time',skipna=True)

dk=xr.Dataset()
dk['test']=(('lat','lon'),fieldb.values)
dk.coords['lat']=fieldb.lat1.values
dk.coords['lon']=fieldb.lon1.values
fieldb=dk['test']

fieldb=fieldb.interp_like(fielda)
field=(fielda+fieldb+fieldc)/3.

field1=ivt_concat_era5_fixed_poleward/ivt_concat_era5_fixed_poleward
field1=field1.sum(dim='time')

field1a=ivt_concat_merra2_fixed_poleward/ivt_concat_merra2_fixed_poleward
field1a=field1a.sum(dim='time')

field1b=ivt_concat_jra55_fixed_poleward/ivt_concat_jra55_fixed_poleward

dk=xr.Dataset()
dk['test']=(('time','lat','lon'),field1b.values)
dk.coords['time']=field1b.time.values
dk.coords['lat']=field1b.lat.values
dk.coords['lon']=field1b.lon.values
field1b=dk['test']


field1b=field1b.interp_like(duration_concat_merra2_fixed_poleward)
field1b=field1b.sum(dim='time')

field_freq=(field1+field1a+field1b)/3.

field=field.where(field_freq>=0.8*43)
fig=plt.figure(figsize=(24,11))#24,12
ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
#cax=ax.pcolormesh(field.lon,field.lat,field,vmin=0,vmax=25,cmap=plt.cm.viridis,transform=ccrs.PlateCarree(),alpha=1.0)   
#cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(5,30,5))
cax=ax.contourf(field.lon,field.lat,field,levels=np.arange(0,33,3),extend='max',cmap=plt.cm.viridis,alpha=1.0)
cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(3,33,6))

g1=ax.gridlines(crs=ccrs.PlateCarree(),draw_labels=True,linewidth=1.5,color='gray',alpha=0.0,linestyle='--')
cbar.ax.tick_params(labelsize=47) 
cbar.set_label('m s$^{-1}$',fontsize=55,labelpad=15)
ax.coastlines(resolution='10m')
countries = cfeature.NaturalEarthFeature(category='cultural',name='admin_0_boundary_lines_land',scale='50m',facecolor='none')
ax.add_feature(countries)
g1.xlabel_style={'size':47,'color':'k'}
g1.ylabel_style={'size':47,'color':'k'}
g1.xformatter=LONGITUDE_FORMATTER
g1.yformatter=LATITUDE_FORMATTER
g1.top_labels=False
g1.right_labels=False

g1.xlocator = mticker.FixedLocator([-120,-60,0,60,120])
            
ax.set_title(r'$\bf{850}$'+' '+r'$\bf{hPa}$'+' '+r'$\bf{wind}$'+' '+r'$\bf{speed}$'+' '+r'$\bf{fixed}$'+' '+r'$\bf{poleward}$',fontsize=60,pad=5)

plt.show()

# %%
fig.savefig(dir_data+'ar_vars_maxes_geomeans_8.png')

# %%
fieldc=s_concat_era5_variable.mean(dim='time',skipna=True)
fielda=s_concat_merra2_variable.mean(dim='time',skipna=True)
fieldb=s_concat_jra55_variable.mean(dim='time',skipna=True)

dk=xr.Dataset()
dk['test']=(('lat','lon'),fieldb.values)
dk.coords['lat']=fieldb.lat1.values
dk.coords['lon']=fieldb.lon1.values
fieldb=dk['test']

fieldb=fieldb.interp_like(fielda)
field=(fielda+fieldb+fieldc)/3.

field1=ivt_concat_era5_variable/ivt_concat_era5_variable
field1=field1.sum(dim='time')

field1a=ivt_concat_merra2_variable/ivt_concat_merra2_variable
field1a=field1a.sum(dim='time')

field1b=ivt_concat_jra55_variable/ivt_concat_jra55_variable

dk=xr.Dataset()
dk['test']=(('time','lat','lon'),field1b.values)
dk.coords['time']=field1b.time.values
dk.coords['lat']=field1b.lat.values
dk.coords['lon']=field1b.lon.values
field1b=dk['test']


field1b=field1b.interp_like(duration_concat_merra2_variable)
field1b=field1b.sum(dim='time')

field_freq=(field1+field1a+field1b)/3.

field=field.where(field_freq>=0.8*43)

fig=plt.figure(figsize=(24,11))#24,12
ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
#cax=ax.pcolormesh(field.lon,field.lat,field,vmin=0,vmax=25,cmap=plt.cm.viridis,transform=ccrs.PlateCarree(),alpha=1.0)   
#cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(5,30,5))
cax=ax.contourf(field.lon,field.lat,field,levels=np.arange(0,33,3),extend='max',cmap=plt.cm.viridis,alpha=1.0)
cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(3,33,6))

g1=ax.gridlines(crs=ccrs.PlateCarree(),draw_labels=True,linewidth=1.5,color='gray',alpha=0.0,linestyle='--')
cbar.ax.tick_params(labelsize=47) 
cbar.set_label('m s$^{-1}$',fontsize=55,labelpad=15)
ax.coastlines(resolution='10m')
countries = cfeature.NaturalEarthFeature(category='cultural',name='admin_0_boundary_lines_land',scale='50m',facecolor='none')
ax.add_feature(countries)
g1.xlabel_style={'size':47,'color':'k'}
g1.ylabel_style={'size':47,'color':'k'}
g1.xformatter=LONGITUDE_FORMATTER
g1.yformatter=LATITUDE_FORMATTER
g1.top_labels=False
g1.right_labels=False

g1.xlocator = mticker.FixedLocator([-120,-60,0,60,120])
            
ax.set_title(r'$\bf{850}$'+' '+r'$\bf{hPa}$'+' '+r'$\bf{wind}$'+' '+r'$\bf{speed}$'+' '+r'$\bf{variable}$',fontsize=64,pad=5)

plt.show()

# %%
fig.savefig(dir_data+'ar_vars_maxes_geomeans_9.png')

# %%
fieldc=mfc_concat_era5_fixed.mean(dim='time',skipna=True)
fielda=mfc_concat_merra2_fixed.mean(dim='time',skipna=True)
field=(fielda+fieldc)/2./1e-4

field1=ivt_concat_era5_fixed/ivt_concat_era5_fixed
field1=field1.sum(dim='time')

field1a=ivt_concat_merra2_fixed/ivt_concat_merra2_fixed
field1a=field1a.sum(dim='time')

field_freq=(field1+field1a)/2.

field=field.where(field_freq>=0.8*43)

fig=plt.figure(figsize=(24,11))#24,12
ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
#cax=ax.pcolormesh(field.lon,field.lat,field,vmin=-1.4,vmax=1.4,cmap=plt.cm.BrBG,transform=ccrs.PlateCarree(),alpha=1.0)   
#cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='both',aspect=15,ticks=[-1,-0.5,0,0.5,1])
cax=ax.contourf(field.lon,field.lat,field,levels=np.arange(-10,11,1),extend='both',cmap=plt.cm.viridis,alpha=1.0)
cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='both',aspect=15)


g1=ax.gridlines(crs=ccrs.PlateCarree(),draw_labels=True,linewidth=1.5,color='gray',alpha=0.0,linestyle='--')
cbar.ax.tick_params(labelsize=47) 
cbar.set_label('10$^{-4}$ kg m$^{-2}$ s$^{-1}$',fontsize=55,labelpad=5)
ax.coastlines(resolution='10m')
countries = cfeature.NaturalEarthFeature(category='cultural',name='admin_0_boundary_lines_land',scale='50m',facecolor='none')
ax.add_feature(countries)
g1.xlabel_style={'size':47,'color':'k'}
g1.ylabel_style={'size':47,'color':'k'}
g1.xformatter=LONGITUDE_FORMATTER
g1.yformatter=LATITUDE_FORMATTER
g1.top_labels=False
g1.right_labels=False

g1.xlocator = mticker.FixedLocator([-120,-60,0,60,120])
            
ax.set_title(r'$\bf{MFC}$'+' '+r'$\bf{fixed}$',fontsize=64,pad=5)

plt.show()

# %%
fig.savefig(dir_data+'ar_vars_maxes_geomeans_10.png')

# %%
fieldc=mfc_concat_era5_fixed_poleward.mean(dim='time',skipna=True)
fielda=mfc_concat_merra2_fixed_poleward.mean(dim='time',skipna=True)
field=(fielda+fieldc)/2./1e-4

field1=ivt_concat_era5_fixed_poleward/ivt_concat_era5_fixed_poleward
field1=field1.sum(dim='time')

field1a=ivt_concat_merra2_fixed_poleward/ivt_concat_merra2_fixed_poleward
field1a=field1a.sum(dim='time')

field_freq=(field1+field1a)/2.

field=field.where(field_freq>=0.8*43)

fig=plt.figure(figsize=(24,11))#24,12
ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
#cax=ax.pcolormesh(field.lon,field.lat,field,vmin=-1.4,vmax=1.4,cmap=plt.cm.BrBG,transform=ccrs.PlateCarree(),alpha=1.0)   
#cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='both',aspect=15,ticks=[-1,-0.5,0,0.5,1])
cax=ax.contourf(field.lon,field.lat,field,levels=np.arange(-10,11,1),extend='both',cmap=plt.cm.viridis,alpha=1.0)
cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='both',aspect=15)


g1=ax.gridlines(crs=ccrs.PlateCarree(),draw_labels=True,linewidth=1.5,color='gray',alpha=0.0,linestyle='--')
cbar.ax.tick_params(labelsize=47) 
cbar.set_label('10$^{-4}$ kg m$^{-2}$ s$^{-1}$',fontsize=55,labelpad=5)
ax.coastlines(resolution='10m')
countries = cfeature.NaturalEarthFeature(category='cultural',name='admin_0_boundary_lines_land',scale='50m',facecolor='none')
ax.add_feature(countries)
g1.xlabel_style={'size':47,'color':'k'}
g1.ylabel_style={'size':47,'color':'k'}
g1.xformatter=LONGITUDE_FORMATTER
g1.yformatter=LATITUDE_FORMATTER
g1.top_labels=False
g1.right_labels=False

g1.xlocator = mticker.FixedLocator([-120,-60,0,60,120])
            
ax.set_title(r'$\bf{MFC}$'+' '+r'$\bf{fixed}$'+' '+r'$\bf{poleward}$',fontsize=64,pad=5)

plt.show()

# %%
fig.savefig(dir_data+'ar_vars_maxes_geomeans_11.png')

# %%
fieldc=mfc_concat_era5_variable.mean(dim='time',skipna=True)
fielda=mfc_concat_merra2_variable.mean(dim='time',skipna=True)
field=(fielda+fieldc)/2./1e-4

field1=ivt_concat_era5_variable/ivt_concat_era5_variable
field1=field1.sum(dim='time')

field1a=ivt_concat_merra2_variable/ivt_concat_merra2_variable
field1a=field1a.sum(dim='time')

field_freq=(field1+field1a)/2.

field=field.where(field_freq>=0.8*43)

fig=plt.figure(figsize=(24,11))#24,12
ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
#cax=ax.pcolormesh(field.lon,field.lat,field,vmin=-1.4,vmax=1.4,cmap=plt.cm.BrBG,transform=ccrs.PlateCarree(),alpha=1.0)   
#cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='both',aspect=15,ticks=[-1,-0.5,0,0.5,1])
cax=ax.contourf(field.lon,field.lat,field,levels=np.arange(-10,11,1),extend='both',cmap=plt.cm.viridis,alpha=1.0)
cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='both',aspect=15)


g1=ax.gridlines(crs=ccrs.PlateCarree(),draw_labels=True,linewidth=1.5,color='gray',alpha=0.0,linestyle='--')
cbar.ax.tick_params(labelsize=47) 
cbar.set_label('10$^{-4}$ kg m$^{-2}$ s$^{-1}$',fontsize=55,labelpad=5)
ax.coastlines(resolution='10m')
countries = cfeature.NaturalEarthFeature(category='cultural',name='admin_0_boundary_lines_land',scale='50m',facecolor='none')
ax.add_feature(countries)
g1.xlabel_style={'size':47,'color':'k'}
g1.ylabel_style={'size':47,'color':'k'}
g1.xformatter=LONGITUDE_FORMATTER
g1.yformatter=LATITUDE_FORMATTER
g1.top_labels=False
g1.right_labels=False

g1.xlocator = mticker.FixedLocator([-120,-60,0,60,120])
            
ax.set_title(r'$\bf{MFC}$'+' '+r'$\bf{variable}$',fontsize=64,pad=5)

plt.show()

# %%
fig.savefig(dir_data+'ar_vars_maxes_geomeans_12.png')

# %%
fieldc=duration_concat_era5_fixed.mean(dim='time',skipna=True)
fielda=duration_concat_merra2_fixed.mean(dim='time',skipna=True)
fieldb=duration_concat_jra55_fixed.mean(dim='time',skipna=True)

dk=xr.Dataset()
dk['test']=(('lat','lon'),fieldb.values)
dk.coords['lat']=fieldb.lat.values
dk.coords['lon']=fieldb.lon.values
fieldb=dk['test']

fieldb=fieldb.interp_like(fielda)

field=(fielda+fieldb+fieldc)/3.

field1=duration_concat_era5_fixed/duration_concat_era5_fixed
field1=field1.sum(dim='time')

field1a=duration_concat_merra2_fixed/duration_concat_merra2_fixed
field1a=field1a.sum(dim='time')

field1b=duration_concat_jra55_fixed/duration_concat_jra55_fixed

dk=xr.Dataset()
dk['test']=(('time','lat','lon'),field1b.values)
dk.coords['time']=field1b.time.values
dk.coords['lat']=field1b.lat.values
dk.coords['lon']=field1b.lon.values
field1b=dk['test']


field1b=field1b.interp_like(duration_concat_merra2_fixed)
field1b=field1b.sum(dim='time')

field_freq=(field1+field1a+field1b)/3.

field=field.where(field_freq>=0.9*43)

fig=plt.figure(figsize=(24,11))#24,12
ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
#cax=ax.pcolormesh(field.lon,field.lat,field,vmin=0,vmax=25,cmap=plt.cm.viridis,transform=ccrs.PlateCarree(),alpha=1.0)   
#cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(5,30,5))
cax=ax.contourf(field.lon,field.lat,field,levels=np.arange(1,7,1),extend='max',cmap=plt.cm.viridis,alpha=1.0)
cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(2,7,1))

g1=ax.gridlines(crs=ccrs.PlateCarree(),draw_labels=True,linewidth=1.5,color='gray',alpha=0.0,linestyle='--')
cbar.ax.tick_params(labelsize=47) 
cbar.set_label('Time steps',fontsize=55,labelpad=15)
ax.coastlines(resolution='10m')
countries = cfeature.NaturalEarthFeature(category='cultural',name='admin_0_boundary_lines_land',scale='50m',facecolor='none')
ax.add_feature(countries)
g1.xlabel_style={'size':47,'color':'k'}
g1.ylabel_style={'size':47,'color':'k'}
g1.xformatter=LONGITUDE_FORMATTER
g1.yformatter=LATITUDE_FORMATTER
g1.top_labels=False
g1.right_labels=False

g1.xlocator = mticker.FixedLocator([-120,-60,0,60,120])
            
ax.set_title(r'$\bf{Duration}$'+' '+r'$\bf{fixed}$',fontsize=64,pad=5)

plt.show()

# %%
fig.savefig(dir_data+'ar_vars_maxes_geomeans_13.png')

# %%
fieldc=duration_concat_era5_fixed_poleward.mean(dim='time',skipna=True)
fielda=duration_concat_merra2_fixed_poleward.mean(dim='time',skipna=True)
fieldb=duration_concat_jra55_fixed_poleward.mean(dim='time',skipna=True)

dk=xr.Dataset()
dk['test']=(('lat','lon'),fieldb.values)
dk.coords['lat']=fieldb.lat.values
dk.coords['lon']=fieldb.lon.values
fieldb=dk['test']

fieldb=fieldb.interp_like(fielda)

field=(fielda+fieldb+fieldc)/3.

field1=duration_concat_era5_fixed_poleward/duration_concat_era5_fixed_poleward
field1=field1.sum(dim='time')

field1a=duration_concat_merra2_fixed_poleward/duration_concat_merra2_fixed_poleward
field1a=field1a.sum(dim='time')

field1b=duration_concat_jra55_fixed_poleward/duration_concat_jra55_fixed_poleward

dk=xr.Dataset()
dk['test']=(('time','lat','lon'),field1b.values)
dk.coords['time']=field1b.time.values
dk.coords['lat']=field1b.lat.values
dk.coords['lon']=field1b.lon.values
field1b=dk['test']


field1b=field1b.interp_like(duration_concat_merra2_fixed_poleward)
field1b=field1b.sum(dim='time')

field_freq=(field1+field1a+field1b)/3.

field=field.where(field_freq>=0.9*43)

fig=plt.figure(figsize=(24,11))#24,12
ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
#cax=ax.pcolormesh(field.lon,field.lat,field,vmin=0,vmax=25,cmap=plt.cm.viridis,transform=ccrs.PlateCarree(),alpha=1.0)   
#cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(5,30,5))
cax=ax.contourf(field.lon,field.lat,field,levels=np.arange(1,7,1),extend='max',cmap=plt.cm.viridis,alpha=1.0)
cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(2,7,1))

g1=ax.gridlines(crs=ccrs.PlateCarree(),draw_labels=True,linewidth=1.5,color='gray',alpha=0.0,linestyle='--')
cbar.ax.tick_params(labelsize=47) 
cbar.set_label('Time steps',fontsize=55,labelpad=15)
ax.coastlines(resolution='10m')
countries = cfeature.NaturalEarthFeature(category='cultural',name='admin_0_boundary_lines_land',scale='50m',facecolor='none')
ax.add_feature(countries)
g1.xlabel_style={'size':47,'color':'k'}
g1.ylabel_style={'size':47,'color':'k'}
g1.xformatter=LONGITUDE_FORMATTER
g1.yformatter=LATITUDE_FORMATTER
g1.top_labels=False
g1.right_labels=False

g1.xlocator = mticker.FixedLocator([-120,-60,0,60,120])
            
ax.set_title(r'$\bf{Duration}$'+' '+r'$\bf{fixed}$'+' '+r'$\bf{poleward}$',fontsize=64,pad=5)

plt.show()

# %%
fig.savefig(dir_data+'ar_vars_maxes_geomeans_14.png')

# %%
fieldc=duration_concat_era5_variable.mean(dim='time',skipna=True)
fielda=duration_concat_merra2_variable.mean(dim='time',skipna=True)
fieldb=duration_concat_jra55_variable.mean(dim='time',skipna=True)

dk=xr.Dataset()
dk['test']=(('lat','lon'),fieldb.values)
dk.coords['lat']=fieldb.lat.values
dk.coords['lon']=fieldb.lon.values
fieldb=dk['test']

fieldb=fieldb.interp_like(fielda)

field=(fielda+fieldb+fieldc)/3.

field1=duration_concat_era5_variable/duration_concat_era5_variable
field1=field1.sum(dim='time')

field1a=duration_concat_merra2_variable/duration_concat_merra2_variable
field1a=field1a.sum(dim='time')

field1b=duration_concat_jra55_variable/duration_concat_jra55_variable

dk=xr.Dataset()
dk['test']=(('time','lat','lon'),field1b.values)
dk.coords['time']=field1b.time.values
dk.coords['lat']=field1b.lat.values
dk.coords['lon']=field1b.lon.values
field1b=dk['test']


field1b=field1b.interp_like(duration_concat_merra2_variable)
field1b=field1b.sum(dim='time')

field_freq=(field1+field1a+field1b)/3.

field=field.where(field_freq>=0.9*43)

fig=plt.figure(figsize=(24,11))#24,12
ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
#cax=ax.pcolormesh(field.lon,field.lat,field,vmin=0,vmax=25,cmap=plt.cm.viridis,transform=ccrs.PlateCarree(),alpha=1.0)   
#cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(5,30,5))
cax=ax.contourf(field.lon,field.lat,field,levels=np.arange(1,7,1),extend='max',cmap=plt.cm.viridis,alpha=1.0)
cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(2,7,1))

g1=ax.gridlines(crs=ccrs.PlateCarree(),draw_labels=True,linewidth=1.5,color='gray',alpha=0.0,linestyle='--')
cbar.ax.tick_params(labelsize=47) 
cbar.set_label('Time steps',fontsize=55,labelpad=15)
ax.coastlines(resolution='10m')
countries = cfeature.NaturalEarthFeature(category='cultural',name='admin_0_boundary_lines_land',scale='50m',facecolor='none')
ax.add_feature(countries)
g1.xlabel_style={'size':47,'color':'k'}
g1.ylabel_style={'size':47,'color':'k'}
g1.xformatter=LONGITUDE_FORMATTER
g1.yformatter=LATITUDE_FORMATTER
g1.top_labels=False
g1.right_labels=False

g1.xlocator = mticker.FixedLocator([-120,-60,0,60,120])
            
ax.set_title(r'$\bf{Duration}$'+' '+r'$\bf{variable}$',fontsize=64,pad=5)

plt.show()

# %%
fig.savefig(dir_data+'ar_vars_maxes_geomeans_15.png')

# %%
fieldc=freq_4_concat_era5_fixed.mean(dim='time',skipna=True)
fielda=freq_4_concat_merra2_fixed.mean(dim='time',skipna=True)
fieldb=freq_4_concat_jra55_fixed.mean(dim='time',skipna=True)

dk=xr.Dataset()
dk['test']=(('lat','lon'),fieldb.values)
dk.coords['lat']=fieldb.lat.values
dk.coords['lon']=fieldb.lon.values
fieldb=dk['test']

fieldb=fieldb.interp_like(fielda)

field=(fielda+fieldb+fieldc)/3.

field1=duration_concat_era5_fixed/duration_concat_era5_fixed
field1=field1.sum(dim='time')

field1a=duration_concat_merra2_fixed/duration_concat_merra2_fixed
field1a=field1a.sum(dim='time')

field1b=duration_concat_jra55_fixed/duration_concat_jra55_fixed

dk=xr.Dataset()
dk['test']=(('time','lat','lon'),field1b.values)
dk.coords['time']=field1b.time.values
dk.coords['lat']=field1b.lat.values
dk.coords['lon']=field1b.lon.values
field1b=dk['test']


field1b=field1b.interp_like(duration_concat_merra2_fixed)
field1b=field1b.sum(dim='time')

field_freq=(field1+field1a+field1b)/3.

field=field.where(field_freq>=0.9*43)

fig=plt.figure(figsize=(24,11))#24,12
ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
#cax=ax.pcolormesh(field.lon,field.lat,field,vmin=0,vmax=25,cmap=plt.cm.viridis,transform=ccrs.PlateCarree(),alpha=1.0)   
#cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(5,30,5))
cax=ax.contourf(field.lon,field.lat,field.where(field>0),levels=np.arange(0,55,5),extend='max',cmap=plt.cm.viridis,alpha=1.0)
cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(5,55,10))

g1=ax.gridlines(crs=ccrs.PlateCarree(),draw_labels=True,linewidth=1.5,color='gray',alpha=0.0,linestyle='--')
cbar.ax.tick_params(labelsize=47) 
cbar.set_label('Occurrences yr$^{-1}$',fontsize=55,labelpad=15)
ax.coastlines(resolution='10m')
countries = cfeature.NaturalEarthFeature(category='cultural',name='admin_0_boundary_lines_land',scale='50m',facecolor='none')
ax.add_feature(countries)
g1.xlabel_style={'size':47,'color':'k'}
g1.ylabel_style={'size':47,'color':'k'}
g1.xformatter=LONGITUDE_FORMATTER
g1.yformatter=LATITUDE_FORMATTER
g1.top_labels=False
g1.right_labels=False

g1.xlocator = mticker.FixedLocator([-120,-60,0,60,120])
            
ax.set_title(r'$\bf{Prolonged}$'+' '+r'$\bf{AR}$'+' '+r'$\bf{conditions}$'+' '+r'$\bf{fixed}$',fontsize=64,pad=5)

plt.show()

# %%
fig.savefig(dir_data+'ar_vars_maxes_geomeans_16.png')

# %%
fieldc=freq_4_concat_era5_fixed_poleward.mean(dim='time',skipna=True)
fielda=freq_4_concat_merra2_fixed_poleward.mean(dim='time',skipna=True)
fieldb=freq_4_concat_jra55_fixed_poleward.mean(dim='time',skipna=True)

dk=xr.Dataset()
dk['test']=(('lat','lon'),fieldb.values)
dk.coords['lat']=fieldb.lat.values
dk.coords['lon']=fieldb.lon.values
fieldb=dk['test']

fieldb=fieldb.interp_like(fielda)

field=(fielda+fieldb+fieldc)/3.

field1=duration_concat_era5_fixed_poleward/duration_concat_era5_fixed_poleward
field1=field1.sum(dim='time')

field1a=duration_concat_merra2_fixed_poleward/duration_concat_merra2_fixed_poleward
field1a=field1a.sum(dim='time')

field1b=duration_concat_jra55_fixed_poleward/duration_concat_jra55_fixed_poleward

dk=xr.Dataset()
dk['test']=(('time','lat','lon'),field1b.values)
dk.coords['time']=field1b.time.values
dk.coords['lat']=field1b.lat.values
dk.coords['lon']=field1b.lon.values
field1b=dk['test']


field1b=field1b.interp_like(duration_concat_merra2_fixed_poleward)
field1b=field1b.sum(dim='time')

field_freq=(field1+field1a+field1b)/3.

field=field.where(field_freq>=0.9*43)

fig=plt.figure(figsize=(24,11))#24,12
ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
#cax=ax.pcolormesh(field.lon,field.lat,field,vmin=0,vmax=25,cmap=plt.cm.viridis,transform=ccrs.PlateCarree(),alpha=1.0)   
#cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(5,30,5))
cax=ax.contourf(field.lon,field.lat,field.where(field>0),levels=np.arange(0,55,5),extend='max',cmap=plt.cm.viridis,alpha=1.0)
cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(5,55,10))

g1=ax.gridlines(crs=ccrs.PlateCarree(),draw_labels=True,linewidth=1.5,color='gray',alpha=0.0,linestyle='--')
cbar.ax.tick_params(labelsize=47) 
cbar.set_label('Occurrences yr$^{-1}$',fontsize=55,labelpad=15)
ax.coastlines(resolution='10m')
countries = cfeature.NaturalEarthFeature(category='cultural',name='admin_0_boundary_lines_land',scale='50m',facecolor='none')
ax.add_feature(countries)
g1.xlabel_style={'size':47,'color':'k'}
g1.ylabel_style={'size':47,'color':'k'}
g1.xformatter=LONGITUDE_FORMATTER
g1.yformatter=LATITUDE_FORMATTER
g1.top_labels=False
g1.right_labels=False

g1.xlocator = mticker.FixedLocator([-120,-60,0,60,120])
            
ax.set_title(r'$\bf{Prolonged}$'+' '+r'$\bf{AR}$'+' '+r'$\bf{conditions}$'+' '+r'$\bf{fixed}$'+' '+r'$\bf{poleward}$',fontsize=54,pad=5)

plt.show()

# %%
fig.savefig(dir_data+'ar_vars_maxes_geomeans_17.png')

# %%
fieldc=freq_4_concat_era5_variable.mean(dim='time',skipna=True)
fielda=freq_4_concat_merra2_variable.mean(dim='time',skipna=True)
fieldb=freq_4_concat_jra55_variable.mean(dim='time',skipna=True)

dk=xr.Dataset()
dk['test']=(('lat','lon'),fieldb.values)
dk.coords['lat']=fieldb.lat.values
dk.coords['lon']=fieldb.lon.values
fieldb=dk['test']

fieldb=fieldb.interp_like(fielda)

field=(fielda+fieldb+fieldc)/3.

field1=duration_concat_era5_variable/duration_concat_era5_variable
field1=field1.sum(dim='time')

field1a=duration_concat_merra2_variable/duration_concat_merra2_variable
field1a=field1a.sum(dim='time')

field1b=duration_concat_jra55_variable/duration_concat_jra55_variable

dk=xr.Dataset()
dk['test']=(('time','lat','lon'),field1b.values)
dk.coords['time']=field1b.time.values
dk.coords['lat']=field1b.lat.values
dk.coords['lon']=field1b.lon.values
field1b=dk['test']


field1b=field1b.interp_like(duration_concat_merra2_variable)
field1b=field1b.sum(dim='time')

field_freq=(field1+field1a+field1b)/3.

field=field.where(field_freq>=0.9*43)

fig=plt.figure(figsize=(24,11))#24,12
ax=plt.subplot(1,1,1,projection=ccrs.PlateCarree())
#cax=ax.pcolormesh(field.lon,field.lat,field,vmin=0,vmax=25,cmap=plt.cm.viridis,transform=ccrs.PlateCarree(),alpha=1.0)   
#cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(5,30,5))
cax=ax.contourf(field.lon,field.lat,field.where(field>0),levels=np.arange(0,55,5),extend='max',cmap=plt.cm.viridis,alpha=1.0)
cbar=plt.colorbar(cax,pad=0,fraction=0.046,extend='max',aspect=15,ticks=np.arange(5,55,10))

g1=ax.gridlines(crs=ccrs.PlateCarree(),draw_labels=True,linewidth=1.5,color='gray',alpha=0.0,linestyle='--')
cbar.ax.tick_params(labelsize=47) 
cbar.set_label('Occurrences yr$^{-1}$',fontsize=55,labelpad=15)
ax.coastlines(resolution='10m')
countries = cfeature.NaturalEarthFeature(category='cultural',name='admin_0_boundary_lines_land',scale='50m',facecolor='none')
ax.add_feature(countries)
g1.xlabel_style={'size':47,'color':'k'}
g1.ylabel_style={'size':47,'color':'k'}
g1.xformatter=LONGITUDE_FORMATTER
g1.yformatter=LATITUDE_FORMATTER
g1.top_labels=False
g1.right_labels=False

g1.xlocator = mticker.FixedLocator([-120,-60,0,60,120])
            
ax.set_title(r'$\bf{Prolonged}$'+' '+r'$\bf{AR}$'+' '+r'$\bf{conditions}$'+' '+r'$\bf{variable}$',fontsize=64,pad=5)

plt.show()

# %%
fig.savefig(dir_data+'ar_vars_maxes_geomeans_18.png')
