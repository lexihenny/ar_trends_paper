.04434065768089, 137.06550812337622, 128.27923878485439, 124.39993134034344, 127.9888346704779, 140.00183183103474, 159.0462766473905, 141.63707080236225, 127.42267035702639, 122.28249387007355, 116.11594553378569, 127.38405870113895, 135.562687415452, 140.5679424506031, 108.2768515969274, 112.80756476901047, 123.70078316454777, 136.82092931045273, 155.96432929782225, 138.1388608547562, 137.0130408572685, 122.56372742822313, 125.91514409728536, 128.15205561968907]

# %%
yrs=np.arange(1980,2024,1)
months=np.arange(1,13,1)
ivt_mean_list_merra2=[]
for i in range(len(yrs)):
    print(yrs[i])
    yr_str=str(yrs[i])
    for j in range(len(months)):
        if months[j]<10:
            month_str='0'+str(months[j])
        else:
            month_str=str(months[j])
            
        files=glob.glob('/Users/ahenny/MERRA2_*'+'tavgM*'+yr_str+month_str+'.SUB.nc')
        if len(files)>1:
            print(files)
            sys.exit()
        else:
            ds=xr.open_dataset(files[0])
            ivt=np.sqrt(ds['UFLXQV']**2+ds['VFLXQV']**2)
            weights=np.cos(np.deg2rad(ds.lat))
            ivt_weighted=ivt.weighted(weights)
            ivt_mean=ivt_weighted.mean(dim=('lat','lon'),skipna=True).values.tolist()[0]
            ivt_mean_list_merra2.append(ivt_mean)

# %%
running_mean_era5=[]
for i in range(6,len(ivt_mean_list_era5)-6):
    ivt_slice=ivt_mean_list_era5[i-6:i+6]
    slice_mean=float(sum(ivt_slice))/float(len(ivt_slice))
    running_mean_era5.append(slice_mean)
    
running_mean_merra2=[]
for i in range(6,len(ivt_mean_list_merra2)-6):
    ivt_slice=ivt_mean_list_merra2[i-6:i+6]
    slice_mean=float(sum(ivt_slice))/float(len(ivt_slice))
    running_mean_merra2.append(slice_mean)
    
running_mean_jra55=[]
for i in range(6,len(ivt_mean_list_jra55)-6):
    ivt_slice=ivt_mean_list_jra55[i-6:i+6]
    slice_mean=float(sum(ivt_slice))/float(len(ivt_slice))
    running_mean_jra55.append(slice_mean)

fig=plt.figure(figsize=(12,12))
ax=plt.subplot(1,1,1)
x_arr=np.arange(1940,2024,1./12.)
ax.plot(x_arr[6:-6],running_mean_era5,color='r',linewidth=4.0,label='ERA5')
x_arr=np.arange(1980,2024,1./12.)
ax.plot(x_arr[6:-6],running_mean_merra2,color='b',linewidth=4.0,label='MERRA-2')
x_arr=np.arange(1958,2024,1./12.)
ax.plot(x_arr[6:-6],running_mean_jra55,color='orange',linewidth=4.0,label='JRA-55')
ax.tick_params(labelsize=18)
ax.set_xlabel('Year',fontsize=20)
ax.set_ylabel('kg m$^{-1}$ s$^{-1}$',fontsize=20)
ax.set_title(r'$\bf{IVT}$'+' '+r'$\bf{from}$'+' '+r'$\bf{monthly}$'+' '+r'$\bf{mean}$'+' '+r'$\bf{components}$',fontsize=28)
plt.legend(loc='upper left',fontsize=18)
plt.show()

# %%
yrs=np.arange(1940,2024,1)
ivt_list_era5=[]
for i in range(len(yrs)):
    ivt_sel=ivt_mean_list_era5[12*i:12*(i+1)]
    ivt_mean=float(sum(ivt_sel))/float(len(ivt_sel))
    ivt_list_era5.append(ivt_mean)
    
yrs=np.arange(1980,2024,1)
ivt_list_merra2=[]
for i in range(len(yrs)):
    ivt_sel=ivt_mean_list_merra2[12*i:12*(i+1)]
    ivt_mean=float(sum(ivt_sel))/float(len(ivt_sel))
    ivt_list_merra2.append(ivt_mean)
    
yrs=np.arange(1958,2024,1)
ivt_list_jra55=[]
for i in range(len(yrs)):
    ivt_sel=ivt_mean_list_jra55[12*i:12*(i+1)]
    ivt_mean=float(sum(ivt_sel))/float(len(ivt_sel))
    ivt_list_jra55.append(ivt_mean)

fig=plt.figure(figsize=(12,12))
ax=plt.subplot(1,1,1)

yrs=np.arange(1980,2024,1)
test=[x for x in ivt_list_merra2]
r1=st.linregress(yrs,test)
change=r1[0]*len(yrs)
mean=float(sum(test))/float(len(test))
label_1='MERRA-2 (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r1[3],3))+')'

yrs=np.arange(1980,2024,1)
test=[x for x in ivt_list_jra55[22:]]
r2=st.linregress(yrs,test)
change=r2[0]*len(yrs)
mean=float(sum(test))/float(len(test))
label_2='JRA-55 (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r2[3],3))+')'

yrs=np.arange(1980,2024,1)
test=[x for x in ivt_list_era5[40:]]
r3=st.linregress(yrs,test)
change=r3[0]*len(yrs)
mean=float(sum(test))/float(len(test))
label_3='ERA5 (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r3[3],3))+')'

ax.plot(np.arange(1980,2024,1),ivt_list_merra2,linewidth=7,label=label_1)#,color='b')
ax.plot(np.arange(1958,2024,1),ivt_list_jra55,linewidth=7,label=label_2)#,color='orange')
ax.plot(np.arange(1940,2024,1),ivt_list_era5,linewidth=7,label=label_3)#,color='forestgreen')

#yrs=np.arange(1980,2024,1)
#ax.plot(yrs,[r1[0]*x+r1[1] for x in yrs],'k',linewidth=7,linestyle='--')
#ax.plot(yrs,[r2[0]*x+r2[1] for x in yrs],'k',linewidth=7,linestyle='--')
#ax.plot(yrs,[r3[0]*x+r3[1] for x in yrs],'k',linewidth=7,linestyle='--')

ax.grid(True)
ax.tick_params(labelsize=(24))
ax.set_xlabel('Year',fontsize=27)
ax.set_ylabel('kg m$^{-1}$ s$^{-1}$',fontsize=27)
ax.set_title(r'$\bf{Monthly}$'+' '+r'$\bf{IVT}$'+' '+r'$\bf{circulation}$',fontsize=40)
ax.set_ylim(111,149)
for axis in ['bottom','top','left','right']:
    ax.spines[axis].set_linewidth(1.5)
plt.legend(loc='upper left',fontsize=23)
plt.show()

# %%
fig.savefig(dir_data+'AR_PAPER_NEW_1.png')
